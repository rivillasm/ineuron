# %% [markdown]
# ![image.png](attachment:d8ab06d7-c5a9-4b1d-86e5-3ddade4b5e69.png)

# %% [markdown]
# ![image.png](attachment:ff240037-1a87-4fb5-aadb-e28d185007f7.png)

# %% [markdown]
# ![image.png](attachment:6b3150d3-f1fe-46e9-8b77-858fca2ab71c.png)

# %% [markdown]
# ![image.png](attachment:674d0117-d123-4325-b0e5-8925886b1efa.png)

# %% [markdown]
# ![image.png](attachment:7b2b4ec7-382e-438d-8328-2144374087a1.png)

# %% [markdown]
# ![image.png](attachment:0f23e842-e085-4758-9246-8c0934819537.png)

# %% [markdown]
# ![image.png](attachment:a2953760-7edc-4552-80b8-1ca6d110d771.png)

# %% [markdown]
# ![image.png](attachment:3460c7c7-0802-4631-97a1-50f63dd03351.png)

# %% [markdown]
# * for this example impure split
#
# ![image.png](attachment:166ab4bf-6b99-4d74-95cb-3f139541d70c.png)

# %% [markdown]
# ![image.png](attachment:d9317cab-dc41-4ada-9fd4-f70732d2eb70.png)
