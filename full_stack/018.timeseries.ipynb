# %% [markdown]
# ![image.png](attachment:284ac7cb-e2d9-426c-978d-a60d9820347a.png)

# %% [markdown]
# ![image.png](attachment:9a8a6088-e972-4274-b907-11230bd9c598.png)

# %% [markdown]
# * multivariant time series
#
# ![image.png](attachment:81538997-4252-4e42-87a4-0955bbeb45fe.png)

# %% [markdown]
# * inivariant time series
#
# ![image.png](attachment:9a4aae07-32e8-40d2-a2c7-a20b45c8cb7f.png)

# %% [markdown]
# ![image.png](attachment:70edf081-2aa6-4bbd-ade4-a12a5f208fd0.png)
