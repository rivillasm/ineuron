# %% [markdown]
# ![image.png](attachment:284ac7cb-e2d9-426c-978d-a60d9820347a.png)

# %% [markdown]
# ![image.png](attachment:9a8a6088-e972-4274-b907-11230bd9c598.png)

# %% [markdown]
# * multivariant time series
#
# ![image.png](attachment:81538997-4252-4e42-87a4-0955bbeb45fe.png)

# %% [markdown]
# * inivariant time series
#
# ![image.png](attachment:9a4aae07-32e8-40d2-a2c7-a20b45c8cb7f.png)

# %% [markdown]
# ![image.png](attachment:70edf081-2aa6-4bbd-ade4-a12a5f208fd0.png)

# %% [markdown]
# ![image.png](attachment:b8a7615e-5d6c-4a32-9e8a-8237b01ef8c0.png)

# %% [markdown]
# ![image.png](attachment:6a0da715-1f3c-4aae-a2d4-8844d16dd7ac.png)

# %% [markdown]
# ![image.png](attachment:4ef7e9c9-db9a-4e01-a23f-e6e00123ae58.png)

# %% [markdown]
# * in time series we use lagging time stamps to predict the value of the independent feature in another time stamp. in other words, based on the previous times (independent features) we are going to predict a next value (independent feature)
#
# ![image.png](attachment:01ebaddb-9c83-41c7-bd53-e299d7ced3ae.png)
#
# ![image.png](attachment:28cb3074-f545-4f42-925b-5ab01df05db0.png)
