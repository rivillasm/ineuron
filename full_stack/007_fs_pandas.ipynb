# %%
import pandas as pd

# %%
df = pd.read_csv("D:\\lh_data\\ineuron\\book1.csv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-4b1ebf665a92> in <module>()
# ----> 1 df = pd.read_csv("D:\\lh_data\\ineuron\\book1.csv")
#       2 df
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# ...

# %%
df = pd.read_csv("D:\\lh_data\\ineuron\\book1.csv", names =["name","email"])
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-69768d0524c9> in <module>()
# ----> 1 df = pd.read_csv("D:\\lh_data\\ineuron\\book1.csv", names =["name","email"])
#       2 df
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
# ...

# %%
df = pd.read_csv("D:\\lh_data\\ineuron\\book1.csv", skiprows=[1,3])
df

# %%
df_locations = pd.read_csv("D:\lh_data\ineuron\\sample-csv\\locations.csv")
df_locations

# %%
df_locations.columns

# %%
df_locations.dtypes

# %%
df_locations[["id","accessibility"]]

# %%
df_books = pd.read_excel("D:\lh_data\ineuron\\Book1.xlsx", sheet_name=0)
df_books
# Out:
#      name                 email   address  pincode    surname
# 0   mario   rivillasm@gmail.com   calgary   560080   rivillas
# 1  mario1  rivillasm1@gmail.com  calgary1   560081  rivillas1
# 2  mario2  rivillasm2@gmail.com  calgary2   560082  rivillas2
# 3  mario3  rivillasm3@gmail.com  calgary3   560083  rivillas3

# %%
df_books = pd.read_excel("D:\lh_data\ineuron\\Book1.xlsx", sheet_name=1)
df_books
# Out:
#        name                email    address  pincode        surname
# 0   diliara   dkhairou@gmail.com   edmonton   560080   khairoullina
# 1  diliara1  dkhairou1@gmail.com  edmonton1   560081  khairoullina1
# 2  diliara2  dkhairou2@gmail.com  edmonton2   560082  khairoullina2
# 3  diliara3  dkhairou3@gmail.com  edmonton3   560083  khairoullina3

# %%
df = pd.ExcelFile("D:\lh_data\ineuron\Book1.xlsx")    # find out the sheets available
df.sheet_names
# Out:
# ['Sheet1', 'Sheet2']

# %%
for i in df.sheet_names:
    df_books_all = pd.read_excel("D:\lh_data\ineuron\\Book1.xlsx", sheet_name=i)

df_books_all
# Out:
#        name                email    address  pincode        surname
# 0   diliara   dkhairou@gmail.com   edmonton   560080   khairoullina
# 1  diliara1  dkhairou1@gmail.com  edmonton1   560081  khairoullina1
# 2  diliara2  dkhairou2@gmail.com  edmonton2   560082  khairoullina2
# 3  diliara3  dkhairou3@gmail.com  edmonton3   560083  khairoullina3

# %%
df_books_all = pd.read_excel("D:\lh_data\ineuron\\Book1.xlsx", sheet_name=None)
print(type(df_books_all))
df_books_all
# Out:
# <class 'dict'>
# {'Sheet1':      name                 email   address  pincode    surname
#  0   mario   rivillasm@gmail.com   calgary   560080   rivillas
#  1  mario1  rivillasm1@gmail.com  calgary1   560081  rivillas1
#  2  mario2  rivillasm2@gmail.com  calgary2   560082  rivillas2
#  3  mario3  rivillasm3@gmail.com  calgary3   560083  rivillas3,
#  'Sheet2':        name                email    address  pincode        surname
#  0   diliara   dkhairou@gmail.com   edmonton   560080   khairoullina
#  1  diliara1  dkhairou1@gmail.com  edmonton1   560081  khairoullina1
#  2  diliara2  dkhairou2@gmail.com  edmonton2   560082  khairoullina2
#  3  diliara3  dkhairou3@gmail.com  edmonton3   560083  khairoullina3}

# %%
df_books_all.keys()
# Out:
# dict_keys(['Sheet1', 'Sheet2'])

# %%
df_books_all.values()
# Out:
# dict_values([     name                 email   address  pincode    surname
# 0   mario   rivillasm@gmail.com   calgary   560080   rivillas
# 1  mario1  rivillasm1@gmail.com  calgary1   560081  rivillas1
# 2  mario2  rivillasm2@gmail.com  calgary2   560082  rivillas2
# 3  mario3  rivillasm3@gmail.com  calgary3   560083  rivillas3,        name                email    address  pincode        surname
# 0   diliara   dkhairou@gmail.com   edmonton   560080   khairoullina
# 1  diliara1  dkhairou1@gmail.com  edmonton1   560081  khairoullina1
# 2  diliara2  dkhairou2@gmail.com  edmonton2   560082  khairoullina2
# 3  diliara3  dkhairou3@gmail.com  edmonton3   560083  khairoullina3])

# %%
df_books_all["Sheet1"]
# Out:
#      name                 email   address  pincode    surname
# 0   mario   rivillasm@gmail.com   calgary   560080   rivillas
# 1  mario1  rivillasm1@gmail.com  calgary1   560081  rivillas1
# 2  mario2  rivillasm2@gmail.com  calgary2   560082  rivillas2
# 3  mario3  rivillasm3@gmail.com  calgary3   560083  rivillas3

# %%
# READING HTML - extracts only the tabular data from the link, no tabular data is not being extracted
#
df = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
df1 = df[0]
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
(df1.dtypes)
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df1.to_csv("test.cvs",index=False)

# %%
# string in json format
d_json = """{"name":"mario rivillas",
    "emailid":"rivillasm@gmail.com",
    "tech":["ML","DL","CV","BD","DA"],
    "plateform":["techneuron","kidsneuron","ineuron"]}"""

# %%
import json

# JSONVIEWER ONLINE TO VALIDATE

# %%
result = json.loads(d_json)
result    # in form of a dictionary
# Out:
# {'name': 'mario rivillas',
#  'emailid': 'rivillasm@gmail.com',
#  'tech': ['ML', 'DL', 'CV', 'BD', 'DA'],
#  'plateform': ['techneuron', 'kidsneuron', 'ineuron']}

# %%
# dataframe from stringt
d = {"name":"mario rivillas",
    "emailid":"rivillasm@gmail.com",
    "tech":["ML","DL","CV"],
    "plateform":["techneuron","kidsneuron","ineuron"]}

f_dict = pd.DataFrame(d)
f_dict
# Out:
#              name              emailid tech   plateform
# 0  mario rivillas  rivillasm@gmail.com   ML  techneuron
# 1  mario rivillas  rivillasm@gmail.com   DL  kidsneuron
# 2  mario rivillas  rivillasm@gmail.com   CV     ineuron

# %%
shoes = [
{ "id": 1, "name": "Air Force 1 Mid Casual", "brand": "Nike", "in_stock": True },
{ "id": 2, "name": "Blazer Mid '77 Casual", "brand": "Nike", "in_stock": True },
{ "id": 3, "name": "One Take Basketball Shoes", "brand": "Jordan", "in_stock": False }
]
shoes
# Out:
# [{'id': 1,
#   'name': 'Air Force 1 Mid Casual',
#   'brand': 'Nike',
#   'in_stock': True},
#  {'id': 2, 'name': "Blazer Mid '77 Casual", 'brand': 'Nike', 'in_stock': True},
#  {'id': 3,
#   'name': 'One Take Basketball Shoes',
#   'brand': 'Jordan',
#   'in_stock': False}]

# %%
del(shoes[0]["brand"])  # deleting an item from a dictionary

# %%
shoes
# Out:
# [{'id': 1, 'name': 'Air Force 1 Mid Casual', 'in_stock': True},
#  {'id': 2, 'name': "Blazer Mid '77 Casual", 'brand': 'Nike', 'in_stock': True},
#  {'id': 3,
#   'name': 'One Take Basketball Shoes',
#   'brand': 'Jordan',
#   'in_stock': False}]

# %% [markdown]
# # EXAMPLE

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
df = pd.read_json(url)
df.head(5)
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
# ...

# %%
import requests

# %%
data = requests.get(url)   # load all the data from a url
data
# Out:
# <Response [200]>

# %%
data1 = data.json()   # show the data into a json format
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46351',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46351/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46351/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46351/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46351',
#   'id': 1167422549,
#   'node_id': 'I_kwDOAA0YD85FlXRV',
#   'number': 46351,
#   'title': 'Question: why use Azure for CI?',
#   'user': {'login': 'jonashaag',
#    'id': 175722,
#    'node_id': 'MDQ6VXNlcjE3NTcyMg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/175722?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jonashaag',
#    'html_url': 'https://github.com/jonashaag',
#    'followers_url': 'https://api.github.com/users/jonashaag/followers',
# ...

# %%
data1[0]["user"]["id"]
# Out:
# 175722

# %%
len(data1)
# Out:
# 30

# %%
for i in range(len(data1)):
    print(i, data1[i]["user"]["id"])
# Out:
# 0 175722
# 1 10647082
# 2 8078968
# 3 20880292
# 4 175722
# 5 175722
# 6 10647082
# 7 15113894
# 8 36619387
# 9 8078968
# 10 7614606
# 11 8078968
# 12 953992
# 13 39624018
# 14 1538165
# 15 19217750
# 16 8519523
# 17 53796099
# 18 41342515
# 19 175722
# 20 3236794
# 21 8238804
# 22 247555
# 23 30958850
# 24 61934744
# 25 73829711
# 26 61934744
# 27 6618166
# 28 726951
# 29 16693035

# %%
df_json_csv = pd.DataFrame(data1, columns=["id","user","url","repository_url","labels_url"])

# %%
type(df_json_csv)
# Out:
# pandas.core.frame.DataFrame

# %%
df_json_csv.to_csv("json.csv")

# %%
df_json_csv.user[0]
# Out:
# {'login': 'jonashaag',
#  'id': 175722,
#  'node_id': 'MDQ6VXNlcjE3NTcyMg==',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/175722?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/jonashaag',
#  'html_url': 'https://github.com/jonashaag',
#  'followers_url': 'https://api.github.com/users/jonashaag/followers',
#  'following_url': 'https://api.github.com/users/jonashaag/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/jonashaag/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/jonashaag/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/jonashaag/subscriptions',
#  'organizations_url': 'https://api.github.com/users/jonashaag/orgs',
#  'repos_url': 'https://api.github.com/users/jonashaag/repos',
#  'events_url': 'https://api.github.com/users/jonashaag/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/jonashaag/received_events',
#  'type': 'User',
# ...

# %%
len(df_json_csv.user[0].keys())
# Out:
# 18

# %%
df_json_csv.user[29]
# Out:
# {'login': 'pjireland',
#  'id': 16693035,
#  'node_id': 'MDQ6VXNlcjE2NjkzMDM1',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/16693035?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/pjireland',
#  'html_url': 'https://github.com/pjireland',
#  'followers_url': 'https://api.github.com/users/pjireland/followers',
#  'following_url': 'https://api.github.com/users/pjireland/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/pjireland/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/pjireland/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/pjireland/subscriptions',
#  'organizations_url': 'https://api.github.com/users/pjireland/orgs',
#  'repos_url': 'https://api.github.com/users/pjireland/repos',
#  'events_url': 'https://api.github.com/users/pjireland/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/pjireland/received_events',
#  'type': 'User',
# ...

# %%
len(df_json_csv.user[29].keys())
# Out:
# 18

# %%
_keys=(df_json_csv.user[29].keys())
_keys
# Out:
# dict_keys(['login', 'id', 'node_id', 'avatar_url', 'gravatar_id', 'url', 'html_url', 'followers_url', 'following_url', 'gists_url', 'starred_url', 'subscriptions_url', 'organizations_url', 'repos_url', 'events_url', 'received_events_url', 'type', 'site_admin'])

# %%
df_json_csv.columns
# Out:
# Index(['id', 'user', 'url', 'repository_url', 'labels_url'], dtype='object')

# %%
test = df_json_csv.copy()
for i in range(test.shape[0]):
    for _key in _keys:
        #print(i,_key)
        name = "loging_"+_key
        test.loc[test.index[i],name]=test.user[i][_key]

# %%
test.columns
# Out:
# Index(['id', 'user', 'url', 'repository_url', 'labels_url', 'loging_login',
#        'loging_id', 'loging_node_id', 'loging_avatar_url',
#        'loging_gravatar_id', 'loging_url', 'loging_html_url',
#        'loging_followers_url', 'loging_following_url', 'loging_gists_url',
#        'loging_starred_url', 'loging_subscriptions_url',
#        'loging_organizations_url', 'loging_repos_url', 'loging_events_url',
#        'loging_received_events_url', 'loging_type', 'loging_site_admin'],
#       dtype='object')

# %%
test.head()
# Out:
#            id                                               user  \
# 0  1167422549  {'login': 'jonashaag', 'id': 175722, 'node_id'...
# 1  1167422110  {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 2  1167417912  {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 3  1167412829  {'login': 'ryansdowning', 'id': 20880292, 'nod...
# 4  1167404425  {'login': 'jonashaag', 'id': 175722, 'node_id'...
#
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# ...

# %% [markdown]
# # New Dataset

# %%
df = pd.read_csv("D:\\lh_data\\ineuron\\titanic.txt")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.dtypes[df.dtypes == 'object']  # outputs the index of the series df.dtypes
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
cat_columns = df.dtypes[df.dtypes == 'object'].index  # outputs the index of the series df.dtypes

# %%
df[cat_columns]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df[cat_columns].describe()   # describe for cathegorical variables
# Out:
#                                 Name   Sex    Ticket    Cabin Embarked
# count                            891   891       891      204      889
# unique                           891     2       681      147        3
# top     Theobald, Mr. Thomas Leonard  male  CA. 2343  B96 B98        S
# freq                               1   577         7        4      644

# %%
len(df[df['Age'].isnull()==True].index)
# Out:
# 177

# %%
df[df['Age'].isnull()==True]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df[df['Fare']==max(df['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
print(f" {df[df.Sex=='female'].shape[0]} females survived from a total of {len(df.Sex)} pasangers")
# Out:
#  314 females survived from a total of 891 pasangers

# %%
print(f" {df[df.Sex=='male'].shape[0]} females survived from a total of {len(df.Sex)} pasangers")
# Out:
#  577 females survived from a total of 891 pasangers

# %%
print(f" {len(df[df.Survived==True])} people survived from a total of {len(df.Survived)} pasangers")
# Out:
#  342 people survived from a total of 891 pasangers

# %%
print(f" {len(df[df.Survived==False])} people died from a total of {len(df.Survived)} pasangers")
# Out:
#  549 people died from a total of 891 pasangers

# %%
print(f" Oldest person in the titanic was {max(df.Age)} year old and his name was: {df[df.Age == max(df.Age)].Name.values[0]}")
# Out:
#  Oldest person in the titanic was 80.0 year old and his name was: Barkworth, Mr. Algernon Henry Wilson

# %%
print(f" first class : {len(df[df.Pclass == 1])} passangers")
print(f" second class : {len(df[df.Pclass == 2])} passangers")
print(f" third class : {len(df[df.Pclass == 3])} passangers")
# Out:
#  first class : 216 passangers
#  second class : 184 passangers
#  third class : 491 passangers

# %%
df.Name
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
print(f" amount of passangers whose name started with 'S' : {len(df.Name[df.Name.str.startswith('S')])}")
# Out:
#  amount of passangers whose name started with 'S' : 86

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['S+P']=df.SibSp + df.Parch
df[['SibSp','Parch','S+P']]
# Out:
#      SibSp  Parch  S+P
# 0        1      0    1
# 1        1      0    1
# 2        0      0    0
# 3        1      0    1
# 4        0      0    0
# ..     ...    ...  ...
# 886      0      0    0
# 887      0      0    0
# 888      1      2    3
# 889      0      0    0
# 890      0      0    0
#
# [891 rows x 3 columns]

# %%
df.Cabin
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
result = df.Cabin.str.extract('([a-zA-Z]+)([^a-zA-Z]+)', expand=True)
result
# Out:
#        0    1
# 0    NaN  NaN
# 1      C   85
# 2    NaN  NaN
# 3      C  123
# 4    NaN  NaN
# ..   ...  ...
# 886  NaN  NaN
# 887    B   42
# 888  NaN  NaN
# 889    C  148
# 890  NaN  NaN
#
# [891 rows x 2 columns]

# %%
df['Cabin_text']=df.Cabin.str.extract('([a-zA-Z]+)', expand=True)
df['Cabin_number']=df.Cabin.str.extract('([^a-zA-Z]+)', expand=True)
df[['Cabin','Cabin_text','Cabin_number']]
# Out:
#     Cabin Cabin_text Cabin_number
# 0     NaN        NaN          NaN
# 1     C85          C           85
# 2     NaN        NaN          NaN
# 3    C123          C          123
# 4     NaN        NaN          NaN
# ..    ...        ...          ...
# 886   NaN        NaN          NaN
# 887   B42          B           42
# 888   NaN        NaN          NaN
# 889  C148          C          148
# 890   NaN        NaN          NaN
#
# [891 rows x 3 columns]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  S+P Cabin_text  \
# 0      0         A/5 21171   7.2500   NaN        S    1        NaN
# 1      0          PC 17599  71.2833   C85        C    1          C
# 2      0  STON/O2. 3101282   7.9250   NaN        S    0        NaN
# ...

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
sum(df.Sex == "male")
# Out:
# 577

# %%
df.groupby("Sex")["Sex"].count()
# Out:
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64

# %%
df.groupby("Pclass")["Pclass"].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %%
import re
replace = re.compile("([a-zA-Z]+)")
df["Cabin"].str.extract(replace)
# Out:
#        0
# 0    NaN
# 1      C
# 2    NaN
# 3      C
# 4    NaN
# ..   ...
# 886  NaN
# 887    B
# 888  NaN
# 889    C
# 890  NaN
#
# [891 rows x 1 columns]

# %%
df["Cabin"].str.replace(replace,"")
# Out:
# 0      NaN
# 1       85
# 2      NaN
# 3      123
# 4      NaN
#       ...
# 886    NaN
# 887     42
# 888    NaN
# 889    148
# 890    NaN
# Name: Cabin, Length: 891, dtype: object

# %% [markdown]
# # another dataset

# %%
df1 = pd.read_csv("D:\\lh_data\\ineuron\\bank\\bank.csv", sep=";")
df1
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
df1.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
print(f" how many campaign available : {len(set(df1.campaign))}")
# Out:
#  how many campaign available : 32

# %%
len(df1.campaign.unique())
# Out:
# 32

# %%
print(f" how many users have housing and personal loans ")
print(f' {len(df1[(df1["housing"]=="yes") & (df1["loan"]=="yes")])} users have housing and loans')
# Out:
#  how many users have housing and personal loans
#  406 users have housing and loans

# %%
print(f' there are {len(df1[(df1["age"]>60)])} persons older than 60 years ')
# Out:
#  there are 127 persons older than 60 years

# %%
print(f" {df1['month'].value_counts().idxmax()} is the month that we targeted most of the customers")
# Out:
#  may is the month that we targeted most of the customers

# %%
print(f" {df1.contact.value_counts().idxmax()} is the month that we targeted most of the customers")
# Out:
#  cellular is the month that we targeted most of the customers

# %%
df1['month'].value_counts().idxmax()
# Out:
# 'may'

# %%
print(f" {len(df1[df1['balance']<0])} customers with negative balances")
# Out:
#  366 customers with negative balances

# %%
df1.contact.value_counts()
# Out:
# cellular     2896
# unknown      1324
# telephone     301
# Name: contact, dtype: int64

# %%
df1_grouped = df1.groupby(['contact','y']).count()
df1_grouped
# Out:
#                 age   job  marital  education  default  balance  housing  \
# contact   y
# cellular  no   2480  2480     2480       2480     2480     2480     2480
#           yes   416   416      416        416      416      416      416
# telephone no    257   257      257        257      257      257      257
#           yes    44    44       44         44       44       44       44
# unknown   no   1263  1263     1263       1263     1263     1263     1263
#           yes    61    61       61         61       61       61       61
#
#                loan   day  month  duration  campaign  pdays  previous  \
# contact   y
# cellular  no   2480  2480   2480      2480      2480   2480      2480
#           yes   416   416    416       416       416    416       416
# telephone no    257   257    257       257       257    257       257
#           yes    44    44     44        44        44     44        44
# unknown   no   1263  1263   1263      1263      1263   1263      1263
# ...

# %%
max(df1_grouped.loc["cellular","yes"][0],df1_grouped.loc["telephone","yes"][0],df1_grouped.loc["unknown","yes"][0])
# Out:
# 416

# %%
set(df1.education)
# Out:
# {'primary', 'secondary', 'tertiary', 'unknown'}

# %%
df1[df1.education=="primary"]
# Out:
#       age            job   marital education default  balance housing loan  \
# 0      30     unemployed   married   primary      no     1787      no   no
# 9      43       services   married   primary      no      -88     yes  yes
# 18     25    blue-collar    single   primary      no     -221     yes   no
# 26     55    blue-collar   married   primary      no      627     yes   no
# 36     78        retired  divorced   primary      no      229      no   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4480   23    blue-collar   married   primary      no     1158     yes   no
# 4485   53    blue-collar   married   primary      no      238     yes   no
# 4486   37    blue-collar   married   primary      no      378     yes   no
# 4499   45    blue-collar  divorced   primary      no      942      no   no
# 4503   60  self-employed   married   primary      no      362      no  yes
#
# ...

# %%
#edu_levels=list(set(df1.education))
edu_levels=df1.education.unique()
edu_levels
# Out:
# array(['primary', 'secondary', 'tertiary', 'unknown'], dtype=object)

# %%
edu_dict = {level : pd.DataFrame() for level in edu_levels}
edu_dict
# Out:
# {'primary': Empty DataFrame
#  Columns: []
#  Index: [], 'secondary': Empty DataFrame
#  Columns: []
#  Index: [], 'tertiary': Empty DataFrame
#  Columns: []
#  Index: [], 'unknown': Empty DataFrame
#  Columns: []
#  Index: []}

# %%
for key in edu_dict.keys():
    print(key)
    edu_dict[key] = df1[:][df1.education==key]
    print(edu_dict[key].head(3))
# Out:
# primary
#     age          job  marital education default  balance housing loan  \
# 0    30   unemployed  married   primary      no     1787      no   no
# 9    43     services  married   primary      no      -88     yes  yes
# 18   25  blue-collar   single   primary      no     -221     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome   y
# 0   cellular   19   oct        79         1     -1         0  unknown  no
# 9   cellular   17   apr       313         1    147         2  failure  no
# 18   unknown   23   may       250         1     -1         0  unknown  no
# secondary
#    age          job  marital  education default  balance housing loan  \
# 1   33     services  married  secondary      no     4789     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
# 7   39   technician  married  secondary      no      147     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
edu_dict["primary"].head(5)
# Out:
#     age          job   marital education default  balance housing loan  \
# 0    30   unemployed   married   primary      no     1787      no   no
# 9    43     services   married   primary      no      -88     yes  yes
# 18   25  blue-collar    single   primary      no     -221     yes   no
# 26   55  blue-collar   married   primary      no      627     yes   no
# 36   78      retired  divorced   primary      no      229      no   no
#
#       contact  day month  duration  campaign  pdays  previous poutcome    y
# 0    cellular   19   oct        79         1     -1         0  unknown   no
# 9    cellular   17   apr       313         1    147         2  failure   no
# 18    unknown   23   may       250         1     -1         0  unknown   no
# 26    unknown    5   may       247         1     -1         0  unknown   no
# 36  telephone   22   oct        97         1     -1         0  unknown  yes

# %%
edu_dict["secondary"].head(5)
# Out:
#     age          job  marital  education default  balance housing loan  \
# 1    33     services  married  secondary      no     4789     yes  yes
# 4    59  blue-collar  married  secondary      no        0     yes   no
# 7    39   technician  married  secondary      no      147     yes   no
# 10   39     services  married  secondary      no     9374     yes   no
# 11   43       admin.  married  secondary      no      264     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome   y
# 1   cellular   11   may       220         1    339         4  failure  no
# 4    unknown    5   may       226         1     -1         0  unknown  no
# 7   cellular    6   may       151         2     -1         0  unknown  no
# 10   unknown   20   may       273         1     -1         0  unknown  no
# 11  cellular   17   apr       113         2     -1         0  unknown  no

# %%
edu_dict["tertiary"].head(5)
# Out:
#    age            job  marital education default  balance housing loan  \
# 2   35     management   single  tertiary      no     1350     yes   no
# 3   30     management  married  tertiary      no     1476     yes  yes
# 5   35     management   single  tertiary      no      747      no   no
# 6   36  self-employed  married  tertiary      no      307     yes   no
# 8   41   entrepreneur  married  tertiary      no      221     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 5  cellular   23   feb       141         2    176         3  failure  no
# 6  cellular   14   may       341         1    330         2    other  no
# 8   unknown   14   may        57         2     -1         0  unknown  no

# %%
edu_levels=df1.education.unique()
l=[]
for i in edu_levels:
    l.append(df1[:][df1.education==i])

# %%
l[0]
# Out:
#       age            job   marital education default  balance housing loan  \
# 0      30     unemployed   married   primary      no     1787      no   no
# 9      43       services   married   primary      no      -88     yes  yes
# 18     25    blue-collar    single   primary      no     -221     yes   no
# 26     55    blue-collar   married   primary      no      627     yes   no
# 36     78        retired  divorced   primary      no      229      no   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4480   23    blue-collar   married   primary      no     1158     yes   no
# 4485   53    blue-collar   married   primary      no      238     yes   no
# 4486   37    blue-collar   married   primary      no      378     yes   no
# 4499   45    blue-collar  divorced   primary      no      942      no   no
# 4503   60  self-employed   married   primary      no      362      no  yes
#
# ...

# %%
l[1]
# Out:
#       age          job  marital  education default  balance housing loan  \
# 1      33     services  married  secondary      no     4789     yes  yes
# 4      59  blue-collar  married  secondary      no        0     yes   no
# 7      39   technician  married  secondary      no      147     yes   no
# 10     39     services  married  secondary      no     9374     yes   no
# 11     43       admin.  married  secondary      no      264     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar  married  secondary      no     1205     yes   no
# 4515   32     services   single  secondary      no      473     yes   no
# 4516   33     services  married  secondary      no     -333     yes   no
# 4518   57   technician  married  secondary      no      295      no   no
# 4519   28  blue-collar  married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
l[2]
# Out:
#       age            job   marital education default  balance housing loan  \
# 2      35     management    single  tertiary      no     1350     yes   no
# 3      30     management   married  tertiary      no     1476     yes  yes
# 5      35     management    single  tertiary      no      747      no   no
# 6      36  self-employed   married  tertiary      no      307     yes   no
# 8      41   entrepreneur   married  tertiary      no      221     yes   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4501   34     management   married  tertiary      no      297     yes   no
# 4506   42     unemployed  divorced  tertiary      no     -166      no   no
# 4509   51     technician   married  tertiary      no     2506      no   no
# 4517   57  self-employed   married  tertiary     yes    -3313     yes  yes
# 4520   44   entrepreneur    single  tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# # task
#
# ![image.png](attachment:ae7b376a-e9de-4152-99d9-b427b8c5dc40.png)

# %%
import pandas as pd
import numpy as np

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
_series = (df.isna().sum()>200)
_series[_series].index
# Out:
# Index(['Cabin', 'Cabin_text', 'Cabin_number'], dtype='object')

# %%
_series[_series].values
# Out:
# array([ True,  True,  True])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ![image.png](attachment:601685de-da0f-4ee3-af2d-b0a2dbe0c462.png)

# %%
df.dropna(axis=1, thresh=800)   # columns Age/Cabin did not have more than 800 nonNAN values, therefore were removed
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df.fillna(value=df.Age.mean())  # fill all NAN values with the given value
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.groupby("Survived").count()
# Out:
#           PassengerId  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Survived
# 0                 549     549   549  549  424    549    549     549   549
# 1                 342     342   342  342  290    342    342     342   342
#
#           Cabin  Embarked  S+P  Cabin_text  Cabin_number
# Survived
# 0            68       549  549          68            66
# 1           136       340  342         136           134

# %%
df.groupby("Survived").count().T
# Out:
# Survived        0    1
# PassengerId   549  342
# Pclass        549  342
# Name          549  342
# Sex           549  342
# Age           424  290
# SibSp         549  342
# Parch         549  342
# Ticket        549  342
# Fare          549  342
# Cabin          68  136
# Embarked      549  340
# S+P           549  342
# Cabin_text     68  136
# Cabin_number   66  134

# %%
df.groupby("Survived").describe()
# Out:
#          PassengerId                                                     \
#                count        mean         std  min     25%    50%    75%
# Survived
# 0              549.0  447.016393  260.640469  1.0  211.00  455.0  675.0
# 1              342.0  444.368421  252.358840  2.0  250.75  439.5  651.5
#
#                 Pclass            ...  Fare              S+P            \
#             max  count      mean  ...   75%       max  count      mean
# Survived                          ...
# 0         891.0  549.0  2.531876  ...  26.0  263.0000  549.0  0.883424
# 1         890.0  342.0  1.950292  ...  57.0  512.3292  342.0  0.938596
#
#
#                std  min  25%  50%  75%   max
# Survived
# 0         1.830669  0.0  0.0  0.0  1.0  10.0
# 1         1.186076  0.0  0.0  1.0  2.0   6.0
#
# [2 rows x 56 columns]

# %%
df.groupby("Survived").describe()['PassengerId']
# Out:
#           count        mean         std  min     25%    50%    75%    max
# Survived
# 0         549.0  447.016393  260.640469  1.0  211.00  455.0  675.0  891.0
# 1         342.0  444.368421  252.358840  2.0  250.75  439.5  651.5  890.0

# %%
df.groupby("Survived").describe()['PassengerId'].T   # transpossing a dataframe
# Out:
# Survived           0           1
# count     549.000000  342.000000
# mean      447.016393  444.368421
# std       260.640469  252.358840
# min         1.000000    2.000000
# 25%       211.000000  250.750000
# 50%       455.000000  439.500000
# 75%       675.000000  651.500000
# max       891.000000  890.000000

# %%
df1.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
df_1 = l[0]
df_1
# Out:
#       age            job   marital education default  balance housing loan  \
# 0      30     unemployed   married   primary      no     1787      no   no
# 9      43       services   married   primary      no      -88     yes  yes
# 18     25    blue-collar    single   primary      no     -221     yes   no
# 26     55    blue-collar   married   primary      no      627     yes   no
# 36     78        retired  divorced   primary      no      229      no   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4480   23    blue-collar   married   primary      no     1158     yes   no
# 4485   53    blue-collar   married   primary      no      238     yes   no
# 4486   37    blue-collar   married   primary      no      378     yes   no
# 4499   45    blue-collar  divorced   primary      no      942      no   no
# 4503   60  self-employed   married   primary      no      362      no  yes
#
# ...

# %%
df_2 = l[1]
df_2 = df_2.head(20)[["age","job","marital","education"]]
df_2
# Out:
#     age            job   marital  education
# 1    33       services   married  secondary
# 4    59    blue-collar   married  secondary
# 7    39     technician   married  secondary
# 10   39       services   married  secondary
# 11   43         admin.   married  secondary
# 13   20        student    single  secondary
# 14   31    blue-collar   married  secondary
# 16   56     technician   married  secondary
# 19   31       services   married  secondary
# 22   44       services    single  secondary
# 23   44   entrepreneur   married  secondary
# 28   56  self-employed   married  secondary
# 29   53         admin.   married  secondary
# 30   68        retired  divorced  secondary
# 31   31     technician   married  secondary
# 32   59     management   married  secondary
# 35   42         admin.  divorced  secondary
# 37   32    blue-collar   married  secondary
# 38   33     management   married  secondary
# 42   52    blue-collar   married  secondary

# %%
df_3 = l[2]
df_3 = df_3.head(20)[["age","job","marital","education"]]
df_3
# Out:
#     age            job   marital education
# 2    35     management    single  tertiary
# 3    30     management   married  tertiary
# 5    35     management    single  tertiary
# 6    36  self-employed   married  tertiary
# 8    41   entrepreneur   married  tertiary
# 12   36     technician   married  tertiary
# 15   40     management   married  tertiary
# 17   37         admin.    single  tertiary
# 21   42     management  divorced  tertiary
# 24   26      housemaid   married  tertiary
# 25   41     management   married  tertiary
# 33   32     management    single  tertiary
# 34   49     technician   married  tertiary
# 39   23       services    single  tertiary
# 40   38     management    single  tertiary
# 41   36     management    single  tertiary
# 43   32     technician   married  tertiary
# 44   32     technician    single  tertiary
# 45   34     management    single  tertiary
# 53   34     technician   married  tertiary

# %%
pd.concat([df_2,df_3])   # default axis = 0 thus row wise
# Out:
#     age            job   marital  education
# 1    33       services   married  secondary
# 4    59    blue-collar   married  secondary
# 7    39     technician   married  secondary
# 10   39       services   married  secondary
# 11   43         admin.   married  secondary
# 13   20        student    single  secondary
# 14   31    blue-collar   married  secondary
# 16   56     technician   married  secondary
# 19   31       services   married  secondary
# 22   44       services    single  secondary
# 23   44   entrepreneur   married  secondary
# 28   56  self-employed   married  secondary
# 29   53         admin.   married  secondary
# 30   68        retired  divorced  secondary
# 31   31     technician   married  secondary
# 32   59     management   married  secondary
# 35   42         admin.  divorced  secondary
# 37   32    blue-collar   married  secondary
# 38   33     management   married  secondary
# 42   52    blue-collar   married  secondary
# ...

# %%
df_5 = pd.concat([df_2,df_3], axis=1)   #  axis = 1 thus column wise
df_5
# Out:
#      age            job   marital  education   age            job   marital  \
# 1   33.0       services   married  secondary   NaN            NaN       NaN
# 2    NaN            NaN       NaN        NaN  35.0     management    single
# 3    NaN            NaN       NaN        NaN  30.0     management   married
# 4   59.0    blue-collar   married  secondary   NaN            NaN       NaN
# 5    NaN            NaN       NaN        NaN  35.0     management    single
# 6    NaN            NaN       NaN        NaN  36.0  self-employed   married
# 7   39.0     technician   married  secondary   NaN            NaN       NaN
# 8    NaN            NaN       NaN        NaN  41.0   entrepreneur   married
# 10  39.0       services   married  secondary   NaN            NaN       NaN
# 11  43.0         admin.   married  secondary   NaN            NaN       NaN
# 12   NaN            NaN       NaN        NaN  36.0     technician   married
# ...

# %%
df_5.iloc[:,4]   # df.iloc[rowfirst:rowlast, colfirst:collast]; iloc always works for the index of rows and columns starting from 0
# Out:
# 1      NaN
# 2     35.0
# 3     30.0
# 4      NaN
# 5     35.0
# 6     36.0
# 7      NaN
# 8     41.0
# 10     NaN
# 11     NaN
# 12    36.0
# 13     NaN
# 14     NaN
# 15    40.0
# 16     NaN
# 17    37.0
# 19     NaN
# 21    42.0
# 22     NaN
# 23     NaN
# 24    26.0
# 25    41.0
# 28     NaN
# 29     NaN
# 30     NaN
# 31     NaN
# 32     NaN
# 33    32.0
# 34    49.0
# 35     NaN
# 37     NaN
# 38     NaN
# 39    23.0
# 40    38.0
# 41    36.0
# 42     NaN
# 43    32.0
# 44    32.0
# 45    34.0
# 53    34.0
# Name: age, dtype: float64

# %%
df_5.loc[[7,8]]  # .loc looks for the names of the rows and columns
# Out:
#     age         job  marital  education   age           job  marital education
# 7  39.0  technician  married  secondary   NaN           NaN      NaN       NaN
# 8   NaN         NaN      NaN        NaN  41.0  entrepreneur  married  tertiary

# %%
df_5.loc[[7,8],["age"]]
# Out:
#     age   age
# 7  39.0   NaN
# 8   NaN  41.0

# %%
df_2
# Out:
#     age            job   marital  education
# 1    33       services   married  secondary
# 4    59    blue-collar   married  secondary
# 7    39     technician   married  secondary
# 10   39       services   married  secondary
# 11   43         admin.   married  secondary
# 13   20        student    single  secondary
# 14   31    blue-collar   married  secondary
# 16   56     technician   married  secondary
# 19   31       services   married  secondary
# 22   44       services    single  secondary
# 23   44   entrepreneur   married  secondary
# 28   56  self-employed   married  secondary
# 29   53         admin.   married  secondary
# 30   68        retired  divorced  secondary
# 31   31     technician   married  secondary
# 32   59     management   married  secondary
# 35   42         admin.  divorced  secondary
# 37   32    blue-collar   married  secondary
# 38   33     management   married  secondary
# 42   52    blue-collar   married  secondary

# %%
df_3
# Out:
#     age            job   marital education
# 2    35     management    single  tertiary
# 3    30     management   married  tertiary
# 5    35     management    single  tertiary
# 6    36  self-employed   married  tertiary
# 8    41   entrepreneur   married  tertiary
# 12   36     technician   married  tertiary
# 15   40     management   married  tertiary
# 17   37         admin.    single  tertiary
# 21   42     management  divorced  tertiary
# 24   26      housemaid   married  tertiary
# 25   41     management   married  tertiary
# 33   32     management    single  tertiary
# 34   49     technician   married  tertiary
# 39   23       services    single  tertiary
# 40   38     management    single  tertiary
# 41   36     management    single  tertiary
# 43   32     technician   married  tertiary
# 44   32     technician    single  tertiary
# 45   34     management    single  tertiary
# 53   34     technician   married  tertiary

# %% [markdown]
# ![image.png](attachment:654dd5a3-d349-4266-b6af-d708722cf9a5.png)

# %%
pd.merge(df_2,df_3,on="age")   # merge outputs matching values from selected column "age", is a sort of an union
# Out:
#    age        job_x marital_x education_x       job_y marital_y education_y
# 0   42       admin.  divorced   secondary  management  divorced    tertiary
# 1   32  blue-collar   married   secondary  management    single    tertiary
# 2   32  blue-collar   married   secondary  technician   married    tertiary
# 3   32  blue-collar   married   secondary  technician    single    tertiary

# %%
pd.merge(df_2,df_3,on="age", how="left")   # keeps all the rows from left and matches with right
# Out:
#     age          job_x marital_x education_x       job_y marital_y education_y
# 0    33       services   married   secondary         NaN       NaN         NaN
# 1    59    blue-collar   married   secondary         NaN       NaN         NaN
# 2    39     technician   married   secondary         NaN       NaN         NaN
# 3    39       services   married   secondary         NaN       NaN         NaN
# 4    43         admin.   married   secondary         NaN       NaN         NaN
# 5    20        student    single   secondary         NaN       NaN         NaN
# 6    31    blue-collar   married   secondary         NaN       NaN         NaN
# 7    56     technician   married   secondary         NaN       NaN         NaN
# 8    31       services   married   secondary         NaN       NaN         NaN
# 9    44       services    single   secondary         NaN       NaN         NaN
# 10   44   entrepreneur   married   secondary         NaN       NaN         NaN
# ...

# %%
pd.merge(df_2,df_3,on="age", how="right")   # keeps all the rows from right and matches with left
# Out:
#     age        job_x marital_x education_x          job_y marital_y  \
# 0    35          NaN       NaN         NaN     management    single
# 1    35          NaN       NaN         NaN     management    single
# 2    30          NaN       NaN         NaN     management   married
# 3    36          NaN       NaN         NaN  self-employed   married
# 4    36          NaN       NaN         NaN     technician   married
# 5    36          NaN       NaN         NaN     management    single
# 6    41          NaN       NaN         NaN   entrepreneur   married
# 7    41          NaN       NaN         NaN     management   married
# 8    40          NaN       NaN         NaN     management   married
# 9    37          NaN       NaN         NaN         admin.    single
# 10   42       admin.  divorced   secondary     management  divorced
# 11   26          NaN       NaN         NaN      housemaid   married
# 12   32  blue-collar   married   secondary     management    single
# ...

# %%
pd.merge(df_2,df_3,on="age", how="outer")
# Out:
#     age          job_x marital_x education_x          job_y marital_y  \
# 0    33       services   married   secondary            NaN       NaN
# 1    33     management   married   secondary            NaN       NaN
# 2    59    blue-collar   married   secondary            NaN       NaN
# 3    59     management   married   secondary            NaN       NaN
# 4    39     technician   married   secondary            NaN       NaN
# 5    39       services   married   secondary            NaN       NaN
# 6    43         admin.   married   secondary            NaN       NaN
# 7    20        student    single   secondary            NaN       NaN
# 8    31    blue-collar   married   secondary            NaN       NaN
# 9    31       services   married   secondary            NaN       NaN
# 10   31     technician   married   secondary            NaN       NaN
# 11   56     technician   married   secondary            NaN       NaN
# ...

# %%
# JOIN - looks for the indexes of the dataframes

# %% [markdown]
# * NOTE: Both join and merge can be used to combines two dataframes but the join method combines two dataframes on the basis of their indexes whereas the merge method is more versatile and allows us to specify columns beside the index to join on for both dataframes
#
# ![image.png](attachment:1f86868b-4e58-47e0-9f74-b4818c350ac1.png)

# %%
df_2 = df_2.set_index("age")
df_3 = df_3.set_index("age")

# %%
df_2.head()
# Out:
#              job  marital  education
# age
# 33      services  married  secondary
# 59   blue-collar  married  secondary
# 39    technician  married  secondary
# 39      services  married  secondary
# 43        admin.  married  secondary

# %%
df_3.columns=["job3","marital3","education3"]
df_3.head()
# Out:
#               job3 marital3 education3
# age
# 35      management   single   tertiary
# 30      management  married   tertiary
# 35      management   single   tertiary
# 36   self-employed  married   tertiary
# 41    entrepreneur  married   tertiary

# %%
df_2.join(df_3)
# Out:
#                job   marital  education        job3  marital3 education3
# age
# 20         student    single  secondary         NaN       NaN        NaN
# 31     blue-collar   married  secondary         NaN       NaN        NaN
# 31        services   married  secondary         NaN       NaN        NaN
# 31      technician   married  secondary         NaN       NaN        NaN
# 32     blue-collar   married  secondary  management    single   tertiary
# 32     blue-collar   married  secondary  technician   married   tertiary
# 32     blue-collar   married  secondary  technician    single   tertiary
# 33        services   married  secondary         NaN       NaN        NaN
# 33      management   married  secondary         NaN       NaN        NaN
# 39      technician   married  secondary         NaN       NaN        NaN
# 39        services   married  secondary         NaN       NaN        NaN
# 42          admin.  divorced  secondary  management  divorced   tertiary
# ...

# %%
df_2.head()
# Out:
#              job  marital  education
# age
# 33      services  married  secondary
# 59   blue-collar  married  secondary
# 39    technician  married  secondary
# 39      services  married  secondary
# 43        admin.  married  secondary

# %%
df_3.head()
# Out:
#               job3 marital3 education3
# age
# 35      management   single   tertiary
# 30      management  married   tertiary
# 35      management   single   tertiary
# 36   self-employed  married   tertiary
# 41    entrepreneur  married   tertiary

# %%
pd.merge(df_2,df_3,left_on='job',right_on="job3")  # use any column name for merging
# Out:
#               job   marital  education           job3  marital3 education3
# 0        services   married  secondary       services    single   tertiary
# 1        services   married  secondary       services    single   tertiary
# 2        services   married  secondary       services    single   tertiary
# 3        services    single  secondary       services    single   tertiary
# 4      technician   married  secondary     technician   married   tertiary
# 5      technician   married  secondary     technician   married   tertiary
# 6      technician   married  secondary     technician   married   tertiary
# 7      technician   married  secondary     technician    single   tertiary
# 8      technician   married  secondary     technician   married   tertiary
# 9      technician   married  secondary     technician   married   tertiary
# 10     technician   married  secondary     technician   married   tertiary
# ...
