# %%
# to learn more about YOLOV
https://www.youtube.com/c/DSwithBappy/playlists

# %% [markdown]
# # TensorFlow.
#
# https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/tf2_detection_zoo.md

# %% [markdown]
# ![image.png](attachment:f0feb569-87d7-4c9a-b290-07941353a63a.png)

# %% [markdown]
# # preparing the data

# %% [markdown]
# * every framework has its own annotation file format: yolo has txt file, detector2 has a coco format so we annotate the data as a pascal voc format to xml and then to jason file (jason is a coco format), tensorflow uses a pascal cov format to get the xml file and then converts to csv  format (excel csv file with all the info of the xml images) by using a script provided and then to tf

# %% [markdown]
# ![image.png](attachment:8ae11ebe-65d9-450c-944b-f71bb68dedc4.png)

# %% [markdown]
# ![image.png](attachment:c17100a5-edf0-4808-b801-ebe92dd02972.png)

# %% [markdown]
# * manually create the labelmap, showing the item/id/name ; sort of label encoding
#
# ![image.png](attachment:3f43a393-bdba-4959-8bc1-efa849f30ea2.png)

# %% [markdown]
# * so at the end you do not need the xml files once you have created the csv file
# * so each folder should have only the original image and the corresponding .csv file
# ![image.png](attachment:28032ba3-eaa7-43b5-a13a-ab902890d5ba.png)
# ![image.png](attachment:85cbe3af-0235-46df-9f48-d8070653ea2c.png)
# ![image.png](attachment:0861ea2a-1116-46c6-8c97-b50215cfa418.png)

# %% [markdown]
# # open google colab

# %% [markdown]
# * upload the file
# ![image.png](attachment:0ff2c210-bfa6-4c86-9e42-49be3792f690.png)

# %% [markdown]
# * after loading your files (material and notebook) into the google drive
# * mount the drive
# * go to the files location
#
# ![image.png](attachment:ffc75d73-f1b3-4e6d-a742-99e82d7153ad.png)

# %% [markdown]
# * set up:
# * load tensorflow, it is commented since it is already in google colab
# * install tf_slim
#
# ![image.png](attachment:d35ed028-47ea-4c8d-98b2-03c7c1c247ab.png)

# %% [markdown]
# ![image.png](attachment:8eb9c4f7-56f4-4d8c-8685-9881723d85c1.png)

# %% [markdown]
# ![image.png](attachment:3402c476-be51-4392-aea8-c281028f40a7.png)
#
# ![image.png](attachment:9971885e-7f3b-42ea-8921-410490178968.png)

# %% [markdown]
# # clone the tf models from github
#
# ![image.png](attachment:1789613b-c046-4c2c-8a7e-899992911e60.png)

# %% [markdown]
# * call the bash mode
# * then move to "TFOD2|models|research"
# * inside object_detection|protos all the files with extension proto will be converted to extension .py
#
# ![image.png](attachment:30ee5a32-b779-41a4-bf1c-cc5463eb34c7.png)

# %% [markdown]
# * see the result
#
# ![image.png](attachment:aae00792-73fd-494a-b4dc-c15adb520fc6.png)

# %% [markdown]
# from the package folder TFOD2|models|research|object_detection|packages|tf2
# * move to the research folder
# * copy the file setup.py to the research folder
# * install the setup.py for the tensor flow 2
#
# ![image.png](attachment:18001459-114b-4f2c-8a4a-bdd0f0a76acf.png)

# %% [markdown]
# * see the results
#
# ![image.png](attachment:54b31abd-050b-424a-a616-2f07c482d953.png)

# %% [markdown]
# * import required libraries
# * notice there are some patches that are required by google
#
# ![image.png](attachment:de700951-6636-4bb4-9681-7f577bec1fa6.png)

# %% [markdown]
# * make sure you are in the research folder
#
# ![image.png](attachment:39d0bce2-1c7b-4b90-85a1-e1fd60831d8b.png)

# %% [markdown]
# # Note: Upload your data (chess data) , labelmap.pbtxt (inside the training folder) & generate_tfrecord files into google drive and into your research folder
#
# ![image.png](attachment:0a064b2e-5698-4b4a-834d-cece363bbb87.png)

# %% [markdown]
# * download the model manually
#
# ![image.png](attachment:c8072314-8ba4-443a-9cea-1fc6ebdd980e.png)
#
# ![image.png](attachment:33279d0b-fd50-4b1e-9e2a-5a8d241549a4.png)

# %% [markdown]
# * extract the model from the tar format
#
# ![image.png](attachment:49d2d3bd-170f-412b-b43a-167da1b91b12.png)

# %% [markdown]
# * rename the folder for easiness
#
# ![image.png](attachment:6e4a6fda-effb-4cfc-bd18-13d1fcb84c2e.png)

# %% [markdown]
# * make sure:
# * Now create a folder inside research named "training"
# * Move labelmap.pbtxt into training folder
# * Copy pipeline.config into training folder
#     * the pipeline is located in the folder "research|ssd_50"
#     * go to google drive ,
#     * browse to the folder research|ssd_50
#     * find the pipelin.config  and move it to research|training folder
#     *
#     ![image.png](attachment:39d0fb7b-1c22-421d-a1ff-2bc87288a320.png)
#
#     ![image.png](attachment:b168d6cc-7895-4315-802c-cde88bda2f01.png)

# %% [markdown]
# *  Genrating tfrecords file from CSV format
# *  we already have the file .csv format of the records, we need to transform them into tf format
# * execute the generate_tfrecord.py
#
# ![image.png](attachment:dd822936-78ef-4798-a135-4ea89fd1ac93.png)

# %% [markdown]
# ![image.png](attachment:920dfa90-1d40-4df2-99c1-cb8a0439194b.png)

# %% [markdown]
# * repeat the steps for the test data
#
# ![image.png](attachment:1e558f28-bd8c-4ae0-93c9-7994a410476d.png)

# %% [markdown]
# # TRAINING

# %% [markdown]
# Note: ( change config file & move model_main_tf2.py to research)
#
# 1.line no 10/3 ( num_classes: 6)
#
# 2.line no 113/161 ("ssd_50/checkpoint/ckpt-0")  # make sure you are at the search directory
#
# 3.line no 97/162 (num_steps: 20)  #ussualy  7k , 10k epochs when training your data
#
# 4.line no 114/167 (fine_tune_checkpoint_type: "detection")
#
# 5.line no 126/172 (label_map_path: "training/labelmap.pbtxt")   # make sure you are at the search directory
#
# 6.line no 139/182 (label_map_path: "training/labelmap.pbtxt")   # make sure you are at the search directory
#
# 7.line no 128/174 ( input_path: "train.record")
#
# 8.line no 143/186 ( input_path: "test.record")
#
# 9.line no 93/131 (batch_size: 8)  # if it is too big can give memory errors, depends on the hardware
#
# * CTRL+S inside the pipeline.config file to save the changes

# %% [markdown]
# * in google colab go to the pipeline.config and double click on it
# * edited as per indicated above, you will have to find the location of the variables to be changed
#
# ![image.png](attachment:6ed68a28-242f-4b64-b599-84aa1345ea60.png)

# %% [markdown]
# * from the search|object_detection move the model_main_tf2.py file into the research folder
# * go to google drive and move the file from the object_detection to the research folder
#
# ![image.png](attachment:cc80938c-3144-4931-971e-e935ff98d283.png)

# %% [markdown]
# * execute the file
# * set the model directory and the pipeline.config address
#
# ![image.png](attachment:542b996d-7c60-4e34-a8c2-d9a73358200c.png)

# %% [markdown]
# ![image.png](attachment:a462dd5d-93d2-4571-9fd0-9b744b5fa5b0.png)

# %% [markdown]
# # Exporting checkpoint files to Saved Model Format

# %% [markdown]
# ### Note:
# Move exporter_main_v2.py file from object detection to research

# %% [markdown]
# * use the checkpoints files to chreate the inference graph
#
# ![image.png](attachment:d02e8f49-680d-4dc2-b3fb-b16d472565d3.png)

# %% [markdown]
# * in google drive make sure to move the "object_detection|exporter_main_v2.py" file into the research folder
#
# ![image.png](attachment:951f0eba-c461-4418-a2c4-2c1523ec698a.png)

# %% [markdown]
# * the command will convert the checkpoint file into the saved format
#
# ![image.png](attachment:133ec6df-60ac-4ee7-9744-fc8507ba0a56.png)
#
# ![image.png](attachment:b4c32cc7-cd5b-402f-9420-bac99efbd132.png)

# %% [markdown]
# * as  a result the exporte-models gets created inside of the search model
# * that is the final model to be used for the inference
#
# ![image.png](attachment:06998e2b-6830-4a10-90e2-d43cf4c0692e.png)

# %% [markdown]
# # INFERENCING
#
# ![image.png](attachment:87ccc588-bf0a-4094-b423-3d3732d0ec31.png)
