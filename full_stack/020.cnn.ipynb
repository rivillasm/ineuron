# %% [markdown]
# ![image.png](attachment:e6818a57-72af-4296-a870-d2477eba02a4.png)

# %% [markdown]
# ![image.png](attachment:19755107-b6e7-41b4-942a-b2125a7bad22.png)

# %% [markdown]
# ![image.png](attachment:5233fe01-023c-4d0e-a423-611c4ed13846.png)

# %% [markdown]
# ### CNN solves:
# * image classification
# * object detection
# * object segmentation
# * object tracking
# * OCR - extracts text from images

# %% [markdown]
# * open cv libray - python supportive library for computervision

# %% [markdown]
# * fully connected neuroal net
#
# ![image.png](attachment:db8054d2-7fd5-4dc4-8e79-49f375d44b17.png)

# %% [markdown]
# ![image.png](attachment:a16f444d-a427-492a-b9e3-4f17dbec4e00.png)

# %% [markdown]
# ![image.png](attachment:8256c3e8-8a49-4e73-a100-600e2a612c4b.png)

# %% [markdown]
# CNN FULL NETWORK
# * CNN,
# * RELU
# * POOLING
# * FULLY CONNECTED LAYER(ANN)
