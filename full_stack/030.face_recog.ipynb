# %% [markdown]
# ROI with camera static and a line to divide the detection area
#
# 1- resize the entire video
# 2- play with opencv to detect coordinates
#
# ![image.png](attachment:68806f34-9485-482f-8414-ea33b4d71eff.png)

# %% [markdown]
# # FACIAL RECOGNITION
#
# 1- IMAGE(with a face)
#     1.a - find an image : DETECTION --> YES/NO, here you will use  an MTCNN - multi task cascade cnn
#
# ![image.png](attachment:f0994953-4fc2-4613-820f-bc05a9d04160.png)
#
# 2. Recognition - prediction
#    2.a compare VectorP with all the V1, V2,V3...V10, choose the max
#    2.b comapre Vector P with Vavg
#    2.c

# %% [markdown]
# * to find algorithms
#
# https://paperswithcode.com/task/face-detection
#
# ![image.png](attachment:f0510d4b-89fb-4ee3-a1c9-7b1c58041f86.png)
#
# * paper
#
# https://arxiv.org/ftp/arxiv/papers/1604/1604.02878.pdf
#
# ![image.png](attachment:049389b5-9ba1-4cad-9ab9-49de698c69ed.png)

# %% [markdown]
# ![image.png](attachment:d4001fab-da06-420d-a70e-64cbf811e06a.png)

# %% [markdown]
# https://arsfutura.com/magazine/face-recognition-with-facenet-and-mtcnn/

# %% [markdown]
# * FaceMesh
#
# ![image.png](attachment:dda21e72-dc9f-4813-a82d-c3a14d29a869.png)

# %% [markdown]
# ![image.png](attachment:0ba37ad8-1e23-4d8f-9d76-a238087a5a40.png)

# %% [markdown]
# ![image.png](attachment:8bf57e88-a5da-4ac3-a4c0-1d707e737bf1.png)
#
# ![image.png](attachment:cdaf2b0c-141c-4e2a-b5e3-b59ffcc08408.png)

# %% [markdown]
# ![image.png](attachment:6901c44e-f261-4575-9c7e-9e40d22f2d0d.png)

# %% [markdown]
# https://docs.conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html

# %% [markdown]
# ![image.png](attachment:efbaad70-ad33-4aaa-bc24-fb3904fbd1a5.png)
