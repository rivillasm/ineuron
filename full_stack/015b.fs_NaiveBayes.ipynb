# %% [markdown]
# ![image.png](attachment:5b10830b-be36-413c-8eb3-3dcbc8e84342.png)

# %% [markdown]
# ![image.png](attachment:290ee826-bb64-46c9-b505-a7901f09f5eb.png)

# %% [markdown]
# ![image.png](attachment:4c84339b-e98b-4982-9cc2-5f7aada5c461.png)

# %% [markdown]
# ![image.png](attachment:e4e60f20-c4e5-4400-b8c1-27d48f854fac.png)

# %% [markdown]
# ![image.png](attachment:3bb69142-8fba-4f48-b12a-9361c3acaa44.png)

# %% [markdown]
# ![image.png](attachment:adfa3d71-78ce-4278-be83-50cd80cce938.png)

# %% [markdown]
# * for a binary case:
#
# ![image.png](attachment:0c7af69e-9cf1-455b-a78d-41dfa41a9a70.png)

# %% [markdown]
# * we can ignore the denominator, it is the same
#
# ![image.png](attachment:edf3c23c-efc2-48ef-bea0-39353ef7866d.png)

# %% [markdown]
# ![image.png](attachment:d4a1bec7-3364-44fe-b7fd-296adb2f310f.png)

# %% [markdown]
# ### Example
#
# ![image.png](attachment:e7fa3b95-3afc-4dd5-8a3e-606a01bc272a.png)

# %% [markdown]
# ![image.png](attachment:fca738ed-91a7-493e-bc2c-eec5cda27144.png)

# %% [markdown]
# ![image.png](attachment:43ad3969-81e2-4cac-94d6-d46b8f0b5014.png)

# %% [markdown]
# ![image.png](attachment:5a788308-c46d-4f42-9c1c-bf4b565becef.png)

# %% [markdown]
# ![image.png](attachment:612e60c2-6420-4655-8401-2182d065432a.png)

# %% [markdown]
# ![image.png](attachment:f87da14c-2301-4fac-bfb7-a5be964a10b8.png)

# %% [markdown]
# * So based on the calculations the answer is:
#
# ![image.png](attachment:713f46a2-658f-4df9-a4de-f69d5fa5adaf.png)
