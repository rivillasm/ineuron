# %% [markdown]
# * Training data error:
#     - high then it has high bias
#     - low then it has low bias
# * test data error:
#     - high then it has high variance
#     - low then it has low variance

# %% [markdown]
# ![image.png](attachment:8ab38a14-f30c-435c-92df-9862a54a1a30.png)

# %% [markdown]
# ![image.png](attachment:eb5b203c-f93f-4a0a-a3c5-7a3d5918ab47.png)

# %% [markdown]
# ![image.png](attachment:a85bbad1-4e42-4a4d-8ded-1f722d6a6d81.png)
#
# * in ridge regressionm, we add a penalty part (lambda * (square of the slopes))
# * this new parameter avoids the overfitting and creates a more general solution.
# * in the case by adding the penalty part (1.5) the previously obtained value of zero (overfitting solution between two points) became 2.25
# * the next iteration will change the coefficients solution and in this case the the slopes decrease (lets say 0.9).
# * so by adding some values due to the penalty part, the original solution became less overfitting and better generalization.

# %% [markdown]
# ### Relationship between lambda and the slope squared

# %% [markdown]
# * increasing lambda will decrease the slope value, tending to zero,
# * the global minima is decreasing
#
# ![image.png](attachment:c11786e3-c17a-45be-9696-45a39bdb7898.png)

# %% [markdown]
# ![image.png](attachment:b3f53de8-84fc-40af-ad44-bb1d651d84e5.png)
