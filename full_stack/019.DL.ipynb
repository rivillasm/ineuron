# %% [markdown]
# Doubt clearing:
# ![image.png](attachment:1e38fcae-fddc-4d19-b776-8e0fd6535bbc.png)

# %% [markdown]
# ![image.png](attachment:cbb09b39-60d7-4d10-a272-303db8699a5e.png)

# %% [markdown]
# ![image.png](attachment:2307c115-7341-4bc7-bfd4-c565df531afc.png)

# %% [markdown]
# ![image.png](attachment:b0f9c43e-eb57-440a-8e49-5a911f93d59d.png)

# %% [markdown]
# ![image.png](attachment:a2214d92-9a8e-4845-9dd3-0d66cd60a9d4.png)

# %% [markdown]
# ![image.png](attachment:30e7d857-dd6d-4fa3-9084-a571b3c617b5.png)

# %% [markdown]
# ![image.png](attachment:7ce81ff3-1db0-444e-9fb9-67c1f59cc3db.png)

# %% [markdown]
# * Forward propagation starts:
# * first values are input for X1 and X2
# * weigths and bias are initialized randomly
# * the preprocessing is performed
# * the activation function starts and converts the output value between 0-1 to capture nonlinear properties, lets assume the output as 1
# * my real value is zero in this case
# * calculate the loss function [y-ypred]**2 or anyother function (MSE.RMSE.AME)
# * the aim is to reduce the loss value
# * to reduce the loss we need to go and go the backward propagation to update the weights and bias values selected randomly at the beginning
# * 1 epoc is when one forward and one backward propagations are performed
# * repeat forward and backward propagations until the loss functio is decreased
#
# ![image.png](attachment:3a9fb266-a304-456a-bf96-a3c5d8a6f989.png)

# %% [markdown]
# ![image.png](attachment:1dc3b106-c8b5-44e1-a34c-d572c29a62cb.png)
