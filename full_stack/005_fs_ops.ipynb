# %% [markdown]
# # oops - object oriented programing systems
# - we perform taks by using classes and objects
# ![image.png](attachment:1e62d659-02f6-4e4c-bfcd-ea53a700d8f3.png)

# %% [markdown]
# ![image.png](attachment:65ff3ade-0243-4f46-8ab4-3631ef03f562.png)

# %% [markdown]
# ![image.png](attachment:cde1050e-a3b6-408d-acc3-7546de817daa.png)

# %% [markdown]
# ![image.png](attachment:34610dc1-b9d9-4b33-96f4-3c901a03b8b6.png)

# %%
l = [1,2,3,4,5]
for i in l:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ###  Class is a blue print, entity is an object that exists.
#
# Classes provide a means of bundling data and functionality together. Creating a new class creates a new type of object, allowing new instances of that type to be made. Each class instance can have attributes attached to it for maintaining its state. Class instances can also have methods (defined by its class) for modifying its state.

# %%
class car:                  #  creates a class
    # if starts and finishes with __ this is an inbuilt function created by someone 
    # required to create objects
    def __init__(self, brand_name, fuel_type, body_type):  # constructor __init__ helps my class to get an input
        self.brand_name=brand_name
        self.fuel_type=fuel_type
        self.body_type=body_type
        
    def desc_car(self):          # adding self allows this function to be used as a mode in the class
        print(self.brand_name, self.fuel_type, self.body_type)

# %%
innova = car("toyota", "gas", "cadilack")   # creates a variable/instance of a car type

# %% [markdown]
# ### flow of the data
# ![image.png](attachment:bdf0447f-fe09-41cd-aff5-1acfdb9e7d9b.png)

# %%
innova

# %%
innova.desc_car()
# Out:
# toyota gas cadilack

# %%
innova.brand_name
# Out:
# 'toyota'

# %%
nexon = car("tata","petrol","suv")
fortuner = car("toyota","diesel","suv")

# %%
nexon.desc_car()
# Out:
# tata petrol suv

# %%
nexon.fuel_type
# Out:
# 'petrol'

# %% [markdown]
# ![image.png](attachment:98725811-9bfa-4f91-8580-92306731af7e.png)

# %%
class car:                  #  creates a class, we dont need to provide data so we do not use init
    def desc_car(self):          # adding self allows this function to be used as a mode in the class
        print("this is my first method")

# %%
x=car()   # since class does not require input data then car() goes empty

# %%
x.desc_car()
# Out:
# this is my first method

# %%
class list_parser:
        
    def parcer(self,a):
        if type(a)==list:
            for i in a:
                print(i)
                
    def reverser_list(self,z):
        if type(z)==list:
            return l[::-1]

# %%
c = list_parser()  # creates object
c.parcer([2,3,4,5,6])
# Out:
# 2
# 3
# 4
# 5
# 6

# %%
c.reverser_list([2,3,4,5,6])
# Out:
# [5, 4, 3, 2, 1]

# %%
# Out:
# [2, 3, 4, 5, 6]

# %%
class list_parser:
    def __init__(self, l):
        self.l=l
        
    def parcer(self):            # self pointer required so we can use the values of the class
        if type(self.l)==list:   # needs the pointer self to access the class values in other functions
            for i in self.l:
                print(i)
                
    def reverser_list(self):     # # self pointer required so we can use the values of the class
        if type(self.l)==list:   # needs the pointer self to access the class values in other functions
            return self.l[::-1]

# %%
c=list_parser([2,3,4,5,6])
c.l
# Out:
# [2, 3, 4, 5, 6]

# %%
c.parcer()
# Out:
# 2
# 3
# 4
# 5
# 6

# %%
c.reverser_list()
# Out:
# [6, 5, 4, 3, 2]

# %%
class dict_parser:
    
    def __init__(self,d):
        self.d=d
        
    def _keys(self):
        if self._nodict():
            return self.d.keys()
        
    def _values(self):
        if self._nodict():
            return self.d.values()
        
    def _nodict(self):
        if type(self.d)!=dict:
            raise Exception(self.d, " this is not a dictionary ")
        return 1
            
    def _userinput(self):
        self.d =eval( input("input a dictionary")) # evaluates the input
        if self._nodict():
            print(self.d, type(self.d))
            print(self.d.keys())
            print(self.d.values())
            
    def _insert(self):
        if self._nodict():
            k,v = input("add a new key/value pair:").split()
            self.d[k]=v
            print(self.d)
            
    def _insert1(self, **kwargs):   # input several key/value pairs
        for k,v in kwargs.items():
            self.d[k],v
            print(self.d)

# %%
test = dict_parser({'Physics':67, 'Maths':87})

# %%
test

# %%
test._keys()
# Out:
# dict_keys(['Physics', 'Maths'])

# %%
test._values()
# Out:
# dict_values([67, 87])

# %%
test._nodict()
# Out:
# 1

# %%
test._userinput()
# Out:
# input a dictionary {'Physics':67, 'Maths':87}
# {'Physics': 67, 'Maths': 87} <class 'dict'>
# dict_keys(['Physics', 'Maths'])
# dict_values([67, 87])

# %%
test._insert()
# Out:
# add a new key/value pair nombre mario
# {'Physics': 67, 'Maths': 87, 'nombre': 'mario'}

# %%
f=open("mydict.py","w")  # create a file to copy the code above
                         # copy paste the code above
f.close()                # close the file

# %% [markdown]
# * now. you can import that class and use it in another program
#
# ![image.png](attachment:94fca2a4-8c96-4c36-aaec-f04d4260601b.png)

# %% [markdown]
# # assignment
# ![image.png](attachment:fac813c7-3926-4357-828a-f49d7480a6c6.png)

# %% [markdown]
# ## inheritance

# %%
class xyz:
    def __init__(self,a,b,c):
        self.a=a
        self.b=b
        self.c=c
        
    def test(self):  #creates a method
        print("this is my first test method of xyz class")
              
    def test1(self):
        print("this is test1 method of xyz class")
              
    def test2(self):
        print(" this is my test2 of xyz classes")

# %%
p = xyz(1,2,3)  # object of xyz

# %%
print(p.a)  # acces a variable
# Out:
# 1

# %%
p.test2()  # access a method
# Out:
#  this is my test2 of xyz classes

# %%
# inheritance allows  use of the variables/methods from class xyz into class xyz1             
class xyz1(xyz):
    pass

# %%
q = xyz1()  # xzy1 does not need values but since in inherits from xyz you should provide those values!!!
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-84378f2eae99> in <module>()
# ----> 1 q = xyz1()
#
# TypeError: __init__() missing 3 required positional arguments: 'a', 'b', and 'c'

# %%
q = xyz1(5,6,7)

# %%
q.test1()
# Out:
# this is test1 method of xyz class

# %%
q.test2()
# Out:
#  this is my test2 of xyz classes

# %%
q.a
# Out:
# 5

# %%
p.a
# Out:
# 1

# %%
# inheritance allows  use of the variables/methods from class xyz into class xyz1             
class xyz1(xyz):
    def test(self):    # i want to use test from xyz but now i want to change something
        print("this is a test method available in xyz1")

# %%
g = xyz1(3,4,5)

# %%
g.test()  # we use test from xyz but we remodified in xyz1 class
# Out:
# this is a test method available in xyz1

# %%
# class xyz and xyz1 are independent fromeach other
class xyz:
    def __init__(self,a,b,c):
        self.a=a
        self.b=b
        self.c=c
        
    def test(self):  #creates a method
        print("this is my first test method of xyz class")
              
            
            
            
class xyz1:            
    def __init__(self,p,q,v):
        self.p=p
        self.q=q
        self.v=v
        
    def test1(self):
        print("this is a method of xyz1 class")
              
# multiclass inheritance
class child(xyz,xyz1):
    pass

# %%
n = child()  #inherited the variables from the parent classes so the variables should be provided
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-372672b210f7> in <module>()
# ----> 1 n = child()
#
# TypeError: __init__() missing 3 required positional arguments: 'a', 'b', and 'c'

# %%
n = child(4,5,6)

# %% [markdown]
# ![image.png](attachment:3cdf3539-915f-460c-8b02-eb3d651e7f3f.png)
#
# ## note: in the case of child(xyz,xyz1)
# * it will inherits all the variables from the class xyz ONLY (first argument called )
# * it will not inherit the variables from class xyz1 since it was NOT called in the first argument position
# * it will inherits all the functions available in both classes xyz and xyz1, it does not discriminate in position in this cas

# %%
# class xyz and xyz1 are independent fromeach other
class xyz:
    def __init__(self,a,b,c):
        self.a=a
        self.b=b
        self.c=c
        
    def test(self):  #creates a method
        print("this is my first test method of xyz class")
              
            
            
            
class xyz1:            
    def __init__(self,p,q,v):
        self.p=p
        self.q=q
        self.v=v
        
    def test1(self):
        print("this is a method of xyz1 class")
              
# multiclass inheritance
class child(xyz,xyz1):
    def __init__(self,*args):
        xyz.__init__(self,*args)
        xyz1.__init__(self,*args)

# %%
n = child(14,15,16)

# %% [markdown]
# * all variables are inherited from both classes
#
# ![image.png](attachment:78bddb68-e395-496f-927c-a43471cd6231.png)

# %%
n.a
# Out:
# 14

# %%
n.b
# Out:
# 15

# %%
n.c
# Out:
# 16

# %%
n.p
# Out:
# 14

# %%
n.c
# Out:
# 16

# %%
# class xyz and xyz1 are independent fromeach other
class xyz:
    def __init__(self,a,b,c):
        self.a=a
        self.b=b
        self.c=c
        
    def test(self):  #creates a method
        print("this is my first test method of xyz class")
              
            
            
            
class xyz1:            
    def __init__(self,p,q,v):
        self.p=p
        self.q=q
        self.v=v
        
    def test1(self):
        print("this is a method of xyz1 class")
              
# multiclass inheritance
class child(xyz,xyz1):
    def __init__(self,*args, **kwargs):
        xyz.__init__(self,*args)
        xyz1.__init__(self,**kwargs)

# %%
n = child(1,2,3,p=4,q=5,v=6)

# %%
n.a
# Out:
# 1

# %%
n.p
# Out:
# 4

# %%
# class xyz and xyz1 are independent fromeach other
class xyz:
    def __init__(self,a,b,c):
        self.a=a
        self.b=b
        self.c=c
        
    def test(self):  #creates a method
        print("this is my first test method of xyz class")         
            
            
class xyz1(xyz):            
    def test1(self):
        print("this is a methof from class 1")
        
class xyz2(xyz1):
    def test2(self):
        print("this is a methof from class 2")

# %%
# multi label inheritance
v = xyz2()   # xyz2 parent is xyz but it is complaining from variables of grandparent xyz, it inherits all
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-eb62356fd9fe> in <module>()
# ----> 1 v = xyz2()
#
# TypeError: __init__() missing 3 required positional arguments: 'a', 'b', and 'c'

# %%
v=xyz2(100,200,300)  # inherits the variables and function of the parent/grandparent classes

# %% [markdown]
# ![image.png](attachment:8c0a122a-5c8b-404e-9c90-a181a5e09a63.png)

# %% [markdown]
# # TASK
# ![image.png](attachment:40366926-f9e6-4870-84ec-9a41e972fae4.png)

# %%
class io:
    def __init__(self):
        self.filename=filename=str(input("provide a file name:"))
        
    def _write(self):
        f=open(self.filename,"w")
        f.write("add this content into the file")
        f.close
        
    def _read(self):
        f=open(self.filename,"r")
        print(f.read())
        f.close

# %%
x = io()
# Out:
# provide a file name: mario

# %%
x._write()

# %%
x._read()
# Out:
# add this content into the file

# %%
class io1(io):
    pass

# %%
x=io1()
# Out:
# provide a file name: mario1

# %%
x._write()

# %%
x._read()
# Out:
# add this content into the file

# %%
import logging

logging.basicConfig(filename="list1.log", level=logging.DEBUG,format="%(asctime)s %(levelname)s %(message)s", filemode='w')

class file:
    def __init__(self,filename):   # requires filename input
        logging.info("Creating file instance variable")
        self.file=filename
        
    def read(self):
        logging.info("executing read method")
        try:
            with open(f"{self.file}.txt","r") as f:  # creates a text file
                data = f.read()
                return data
        except Exception as e:
            logging.error("Error occurend while opening the file")
            logging.exception(f"error is {e}")
            
    def write(self,data):
        logging.info("executing write method")
        try:
            with open(f"{self.file}.txt","w") as f:
                data=f.write(data)
        except Exception as e:
            logging.error("Something is going worng")
            logging.exception(f"error is {e}")

# %%
obj = file("mario")

# %%
obj.read()
# Out:
# 'esto es loqu e quiero2'

# %%
obj.write("esto es loqu e quiero2")

# %%
class readfile:
    def __init__(self,fileobj,lines):
        self.fileobj=fileobj
        self.lines=lines 
        
    def read(self):
        try:
            f=open(self.fileobj,"r")
            l=f.readline()
            while(l!=""):
                print(l)
                l=f.readline()
        except Exception as e:
             logging.error("Error occurend while opening the file:", e) 
        f.close()
            
    def write(self):
        f=open(self.fileobj,"w")
        f.writelines(self.lines)
        f.close()
        
class readfile2(readfile):
    def read(self):
        print("inheritance of the first readfile class")
        

file="mario.txt"
lines="inserted lines...."

# %%
res = readfile2(file,lines)

# %%
res.write()

# %%
res.read()
# Out:
# inheritance of the first readfile class

# %% [markdown]
# ![image.png](attachment:5532ff38-b66f-4841-9b9b-0db0ffdbbf05.png)

# %% [markdown]
# ![image.png](attachment:52c61888-240e-4ac0-98ba-49613661c464.png)

# %% [markdown]
# # PUBLIC, PRIVATE AND PROTECTED

# %%
class test:
    def __init__(self,a,b,c):
        self.a=a
        self.b=b
        self.c=c
        
u = test(4,5,6)

# %%
u.a
# Out:
# 4

# %%
class test:
    def __init__(self,a,b,c):
        self.a=a
        self.b=b
        self.c=c
        
class test1(test):
    pass

u = test(1,2,3)

# %%
v = test1(4,5,6)  # from test1 i was able to change the original values of variable "a" set in the parent class

# %% [markdown]
# * from test1 we can access the variables a,b,c from the parent class test
#
# ![image.png](attachment:366567dd-d116-429c-97bd-c6e486d990e5.png)

# %%
v.a
# Out:
# 4

# %%
class test:
    def __init__(self):
        self.a=4
        
class test1(test):
    pass

u = test()

# %%
u.a
# Out:
# 4

# %%
v = test1()  # my child class has the variables of the parent available since those are public variables

# %%
v.a
# Out:
# 4

# %%
class test:
    def __init__(self):
        self.a=4
        
class test1(test):
    def __init__(self):  # instructor passing value
        self.a=7
    

u = test()

# %%
u.a
# Out:
# 4

# %%
u = test1()
u.a
# Out:
# 7

# %%
class test:
    def __init__(self):
        self._a=4   # protected variable  "_variablename"
        
class test1(test):
    def __init__(self):  # instructor passing value
        self._a=7

# %%
u=test()
u._a
# Out:
# 4

# %%
v=test1()    # you can access a procted variable
v._a
# Out:
# 7

# %%
class test:
    def __init__(self):
        self.__a=4   # private variable  "_variablename"
        
class test1(test):
    def __init__(self):  # instructor passing value
        self.__a=7

# %%
u=test()   # you CANNOT access a private variable
u.__a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-874f268bd409> in <module>()
#       1 u=test()
# ----> 2 u.__a
#
# AttributeError: 'test' object has no attribute '__a'

# %%
# private variables only have access from their own class, there is not access from subclasses
# protected variable have access from subclasses

# %%
class test:
    def __init__(self,a,b,c):
        self.a=a
        self.b=b
        self.c=c
        
v = test(4,5,6)

# %%
v.c
# Out:
# 6

# %%
class test:
    def __init__(self,a,b,c):
        self.a=a
        self.__b=b  # private variable
        self._c=c
        
v = test(4,5,6)

# %%
v._c
# Out:
# 6

# %%
v.__b
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-93239adde735> in <module>()
# ----> 1 v.__b
#
# AttributeError: 'test' object has no attribute '__b'

# %%
v._test__b   # format to access a private variable  Object._ClassName__PrivateVariable
# Out:
# 5

# %%
class test:
    def __init__(self,a,b,c):
        self.a=a     # public
        self.__b=b  # private variable
        self._c=c   # protected
        
class test1(test):
    pass
        
v = test(4,5,6)

# %%
v.a
# Out:
# 4

# %%
v._c
# Out:
# 6

# %%
v._test__b
# Out:
# 5

# %%
u=test1(100,200,300)

# %%
u.a
# Out:
# 100

# %%
u._c   # child can access the protected variable of a father class
# Out:
# 300

# %%
u._test1__b
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-28b27c9c3546> in <module>()
# ----> 1 u._test1__b
#
# AttributeError: 'test1' object has no attribute '_test1__b'

# %%
u._test__b      # child can access the private variable of a father by following the NOTION/format
                # to access a private variable  Object._ClassName__PrivateVariable
# Out:
# 200

# %% [markdown]
# # EXAMPLE

# %%
class bonouscalculator:
    def __init__(self,empid,emprating):
        self.empid=empid
        self.emprating=emprating
        self.__bonusforratingA="70%"  # private variable
        self.__bonusforratingB="60%"
        self.__bonusforratingC="40%"
        
    def bonuscalculator(self):
        if self.emprating=="A":
            bonus = self.__bonusforratingA   # i can access the private variable within the class
            return bonus
        elif self.emprating=="B":
            bonus = self.__bonusforratingB
            return bonus
        else:
            bonus = self.__bonusforratingC
            return bonus

# %%
emp1 = bonouscalculator(101,"A")
emp2 = bonouscalculator(102
                    ,"A")
emp3 = bonouscalculator(103,"A")

# %%
emp1.bonuscalculator()
# Out:
# '70%'

# %%
emp1.empid
# Out:
# 101

# %%
emp1.empid=1000
emp1.empid  # can be overwritten since it is a public variable
# Out:
# 1000

# %%
emp1.emprating
# Out:
# 'A'

# %%
emp1.emprating="XX"

# %%
emp1.emprating  # can be overwritten since it is a public variable
# Out:
# 'XX'

# %%
emp1.__bonusforratingA  # it is private
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-92-0e0d46bfa807> in <module>()
# ----> 1 emp1.__bonusforratingA
#
# AttributeError: 'bonouscalculator' object has no attribute '__bonusforratingA'

# %%
emp1._bonouscalculator__bonusforratingA
# Out:
# '70%'

# %%
emp1._bonouscalculator__bonusforratingA  = "170" 
emp1._bonouscalculator__bonusforratingA    # you can change/display a private variable but you need to use the corrct NOTION
# Out:
# '170'

# %% [markdown]
# # POLIMORFISM

# %%
class insta:
    def share_stories(self):
        print("this will share my insta story")
    

class facebook:
    def share_stories(self):
        print("this will share my facebook stories")

# %%
def sharestories(app):
    app.share_stories()

# %%
i=insta()   # object of insta
f=facebook()   # object of facebbok class

# %%
sharestories(i)
# Out:
# this will share my insta story

# %%
sharestories(f)
# Out:
# this will share my facebook stories

# %%
class social_media:
    def share_stories(self):
        print("share a stories")
    def upload_pic(self):
        print("this will help you to upload pic on social media")
        
        
class facebook(social_media):  #overwrites the inherited message
    def share_stories(self):
        print("this is a fun for sharing an story for facebook")
    
class insta(social_media):     #overwrites the inherited message
    def share_stories(self):
        print("this will print a story from insta")

# %%
f=facebook()
i=insta()

# %% [markdown]
# ![image.png](attachment:02c2a33f-051d-4616-a37f-8601b61d9359.png)

# %% [markdown]
# ![image.png](attachment:f816e80f-968f-4bc7-8c62-a318c349941a.png)

# %%
# polymorphism, same method used,without being concerned about which class type each object is
f.share_stories()  # will call the overwritten print in the facebbok class and not the original from social_media
# Out:
# this is a fun for sharing an story for facebook

# %%
i.share_stories()  # will call the overwritten print in the insta class and not the original from social_media
# Out:
# this will print a story from insta

# %% [markdown]
# ## Rise Exception class

# %%
class test(Exception):
    def __init__(self,msg):
        self.msg=msg

# %%
try:
    raise(test("this is my own exception class"))
except test as t:
    print(t)
# Out:
# this is my own exception class

# %% [markdown]
# ![image.png](attachment:0e8b9a17-b7da-4648-a4da-088c367c003a.png)

# %%
# Q1  create multiple and multilevel inheritance

"""
 Desc:
  Python program to demonstrate the diamond problem
  (a.k.a. Multiple Inheritance)
"""

# Parent class 1
class TeamMember:
    def __init__(self, name, uid): 
        self.name = name 
        self.uid = uid 
        
#Parent class 2
class Worker:                 
    def __init__(self, pay, jobtitle): 
        self.pay = pay 
        self.jobtitle = jobtitle 
        
# Deriving a child class from the two parent classes
class TeamLeader(TeamMember, Worker):         
    def __init__(self, name, uid, pay, jobtitle, exp): 
        self.exp = exp 
        TeamMember.__init__(self, name, uid) 
        Worker.__init__(self, pay, jobtitle)
        print("Name: {}, Pay: {}, Exp: {}".format(self.name, self.pay, self.exp))

TL = TeamLeader('Jake', 10001, 250000, 'Scrum Master', 5)
# Out:
# Name: Jake, Pay: 250000, Exp: 5

# %% [markdown]
# ![image.png](attachment:f91360ff-d32f-4480-ba63-7c13635f6ebc.png)

# %% [markdown]
# ![image.png](attachment:5165891e-e9cc-4dda-93ea-b13ac3f20b3e.png)

# %%
# Q1  create multilevel inheritance
"""
 Desc:
  Python program to demonstrate multilevel inheritance
"""

class Team:
    def show_Team(self):
        print("This is our Team:")

# Testing class inherited from Team
class Testing(Team):
    TestingName = ""    # static class variable

    def show_Testing(self):
        print(self.TestingName)

# Dev class inherited from Team
class Dev(Team):
    DevName = "" # static class variable

    def show_Dev(self):
        print(self.DevName) 

# Sprint class inherited from Testing and Dev classes
class Sprint(Testing, Dev):
    def show_parent(self):
        print("Testing :", self.TestingName)
        print("Dev :", self.DevName)

s1 = Sprint()  # Object of Sprint class
s1.TestingName = "James"    # it is statics so we can provide a value
s1.DevName = "Barter"       # it is statics so we can provide a value
s1.show_Team()
s1.show_parent()
# Out:
# This is our Team:
# Testing : James
# Dev : Barter

# %%
test1=Testing()
test1.TestingName   # accessing the static class variable
# Out:
# ''

# %%
Testing.TestingName   # calling the static variable  classname.variablename
# Out:
# ''

# %% [markdown]
# ![image.png](attachment:0f791a9c-9847-45b6-a368-1e259b28b561.png)

# %%
# Q2 polymorphism

# with function

class Tomato(): 
    def type(self): 
        print("Vegetable") 
    def color(self):
        print("Red") 
class Apple(): 
    def type(self): 
        print("Fruit") 
    def color(self): 
        print("Red") 

def func(obj):
    obj.type() 
    obj.color()
        
obj_tomato = Tomato() 
obj_apple = Apple() 
func(obj_tomato) 
func(obj_apple)
# Out:
# Vegetable
# Red
# Fruit
# Red

# %%
# with classes

class India():
     def capital(self):
        print("New Delhi")
 
     def language(self):
        print("Hindi and English")

class USA():
     def capital(self):
        print("Washington, D.C.")
 
     def language(self):
        print("English")

obj_ind = India()
obj_usa = USA()

for country in (obj_ind, obj_usa):
    country.capital()
    country.language()
# Out:
# New Delhi
# Hindi and English
# Washington, D.C.
# English

# %%
# Q# create own class for customer exception

# %%
# define Python user-defined exceptions
""" 
 created a user-defined exception called CustomError which inherits from the Exception class. 
 This new exception, like other exceptions, can be raised using the raise statement with an optional 
 error message.
 """

class CustomError(Exception):
    """Base class for other exceptions"""
    pass


class ValueTooSmallError(CustomError):
    """Raised when the input value is too small"""
    pass


class ValueTooLargeError(CustomError):
    """Raised when the input value is too large"""
    pass


# you need to guess this number
number = 10

# user guesses a number until he/she gets it right
while True:
    try:
        i_num = int(input("Enter a number: "))
        if i_num < number:
            raise ValueTooSmallError
        elif i_num > number:
            raise ValueTooLargeError
        break
    except ValueTooSmallError:
        print("This value is too small, try again!")
        print()
    except ValueTooLargeError:
        print("This value is too large, try again!")
        print()

print("Congratulations! You guessed it correctly.")
# Out:
# Enter a number:  5
# This value is too small, try again!
# Enter a number:  12
# This value is too large, try again!
# Enter a number:  10
# Congratulations! You guessed it correctly.

# %%
"""
Here, we have overridden the constructor of the Exception class to accept our own custom arguments 
salary and message. 
Then, the constructor of the parent Exception class is called manually with the self.
message argument using super().

The custom self.salary attribute is defined to be used later.

The inherited __str__ method of the Exception class is then used to display the corresponding 
message when SalaryNotInRangeError is raised.

We can also customize the __str__ method itself by overriding it.
"""


class SalaryNotInRangeError(Exception):
    """Exception raised for errors in the input salary.

    Attributes:
        salary -- input salary which caused the error
        message -- explanation of the error
    """

    def __init__(self, salary, message="Salary is not in (5000, 15000) range"):
        self.salary = salary
        self.message = message
        super().__init__(self.message)

    def __str__(self):                                # overrides the str original exception message
        return f'{self.salary} -> {self.message}'


salary = int(input("Enter salary amount: "))
if not 5000 < salary < 15000:
    raise SalaryNotInRangeError(salary)
# Out:
# Enter salary amount:  1000
# ---------------------------------------------------------------------------
# SalaryNotInRangeError                     Traceback (most recent call last)
# <ipython-input-35-2ea12c93c790> in <module>()
#      33 salary = int(input("Enter salary amount: "))
#      34 if not 5000 < salary < 15000:
# ---> 35     raise SalaryNotInRangeError(salary)
#
# SalaryNotInRangeError: 1000 -> Salary is not in (5000, 15000) range

# %% [markdown]
# ![image.png](attachment:eedd8d1b-13b8-49d9-8258-ba75aec57cd6.png)

# %%
# Q4  Class encapsulation

# %% [markdown]
# ![image.png](attachment:be4af314-0267-4c75-9c6c-a083b05ab5ff.png)
#
# ![image.png](attachment:e28e5b80-85b1-4faa-a2d1-c17f5d710c6c.png)

# %% [markdown]
# ![image.png](attachment:c1a20d1b-9065-42f8-9ec8-08d09a011c52.png)

# %%
# Python program to
# demonstrate protected members
 
# Creating a base class
class Base:
    def __init__(self):
 
        # Protected member
        self._a = 2

# Creating a derived class
class Derived(Base):
    def __init__(self):
 
        # Calling constructor of
        # Base class
        Base.__init__(self)
        print("Calling protected member of base class: ",
              self._a)
 
        # Modify the protected variable:
        self._a = 3
        print("Calling modified protected member outside class: ",
              self._a)
 
 
obj1 = Derived()
 
obj2 = Base()
 
# Calling protected member
# Can be accessed but should not be done due to convention
print("Accessing protected member of obj1: ", obj1._a)
 
# Accessing the protected variable outside
print("Accessing protedted member of obj2: ", obj2._a)
# Out:
# Calling protected member of base class:  2
# Calling modified protected member outside class:  3
# Accessing protected member of obj1:  3
# Accessing protedted member of obj2:  2

# %% [markdown]
# ![image.png](attachment:70108c9b-09ab-4d9d-a5b2-281cf6b55036.png)

# %%
# Python program to
# demonstrate private members
 
# Creating a Base class
 
class Base:
    def __init__(self):
        self.a = "GeeksforGeeks"
        self.__c = "GeeksforGeeks"

# Creating a derived class
class Derived(Base):
    def __init__(self):
 
        # Calling constructor of
        # Base class
        Base.__init__(self)
        print("Calling private member of base class: ")
        print(self.__c)
 
 
# Driver code
obj1 = Base()
print(obj1.a)
 
# Uncommenting print(obj1.c) will
# raise an AttributeError
#print(obj1.c) 

# Uncommenting obj2 = Derived() will
# also raise an AtrributeError as
# private member of base class
# is called inside derived class
#obj2 = Derived()
# Out:
# GeeksforGeeks

# %%
# Q5 overloading and overriding

# %% [markdown]
# ![image.png](attachment:339fb185-32bb-4a4c-8cb7-f9462b7a25be.png)

# %%
# Function to take multiple arguments
def add(datatype, *args):
   
    # if datatype is int
    # initialize answer as 0
    if datatype =='int':
        answer = 0
           
    # if datatype is str
    # initialize answer as ''
    if datatype =='str':
        answer =''
   
    # Traverse through the arguments
    for x in args:
   
        # This will do addition if the 
        # arguments are int. Or concatenation 
        # if the arguments are str
        answer = answer + x
   
    print(answer)

# Integer
add('int', 5, 6)
   
# String
add('str', 'Hi ', 'Geeks')
# Out:
# 11
# Hi Geeks

# %% [markdown]
# ![image.png](attachment:6117523f-28c3-427a-ace3-2133d82a9e92.png)

# %%
class A:
 
    def fun1(self):
        print('feature_1 of class A')
         
    def fun2(self):
        print('feature_2 of class A')

class B(A):     
    # Modified function that is
    # already exist in class A
    def fun1(self):
        print('Modified feature_1 of class A by class B')   
         
    def fun3(self):
        print('feature_3 of class B')
         
# Create instance
obj = B()
     
# Call the override function
obj.fun1()
# Out:
# Modified feature_1 of class A by class B
