# %% [markdown]
# ![image.png](attachment:fbbd574b-fa63-4c07-8c8b-a13de682f8ad.png)

# %% [markdown]
# ![image.png](attachment:6090b6d0-2cad-49dc-add6-057201f3d0b1.png)

# %% [markdown]
# ![image.png](attachment:d1ae5770-7c7d-4c03-9dde-9f50b0b604c7.png)

# %% [markdown]
# ![image.png](attachment:ebda3aed-7f15-4e19-8c4e-883a2a112852.png)

# %% [markdown]
# * then the process gets repeated, each point is assigned to the nearest centroid and then the centroid gets recalcualed again...  until it stops improving
#
# ![image.png](attachment:6b1fddcd-c332-44d6-95fd-fd2bd47af201.png)

# %% [markdown]
# * to calculate how many centroids are required we calculate WCSS within cluster sum of squared, and we try to reduce it as much as possible!
#
# ![image.png](attachment:052ef29a-4807-4b21-ab66-bb810d225edc.png)
#
# then we can graph all this WCSS and from that graph ELBOW METHOD you select the best K value
#
# ![image.png](attachment:972d3574-ba7a-44b9-bb45-5dfeef7fab95.png)

# %% [markdown]
# * k means plus plus is a method used to initialize the centroids away from each other to avoid such cases where the initialization of the centroids produce undesirable results

# %% [markdown]
# ![image.png](attachment:b1308b43-2836-4030-a1b8-2dd4507c5454.png)

# %% [markdown]
# ![image.png](attachment:8dcb14e3-261a-4d22-a6b0-4f3eaf4c697d.png)
