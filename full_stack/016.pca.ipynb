# %% [markdown]
# # pca

# %% [markdown]
# * why the accuracy decreases when the amount of features increase?
#
#     * maybe some features are not related to the output feature
#     * training accuracy will be high but test accuracy will be low due to overfitting
#
# * curse of dimensionality : after certain threasure, increasing features will decrease the accuracy of the model
#
# ![image.png](attachment:384ac056-b620-4138-9089-ca9ee4d06a20.png)

# %% [markdown]
# ![image.png](attachment:239dd838-d878-49be-a386-e0a32d6c0935.png)

# %% [markdown]
# ![image.png](attachment:cbe6c9c3-3a99-4094-945a-9c908bd91996.png)

# %% [markdown]
# ![image.png](attachment:acdb21f1-e698-41c3-ac98-6ebdb5dfef73.png)

# %% [markdown]
# ![image.png](attachment:f508a36e-186b-4bc0-a469-cf82bc33be11.png)

# %% [markdown]
# ![image.png](attachment:4b8226d2-502a-4e67-b2a9-42558cd66c22.png)

# %% [markdown]
# ![image.png](attachment:fd1556e0-29bd-44aa-96ca-d7b750309cb7.png)

# %% [markdown]
# ![image.png](attachment:651bf5b7-fb18-4f4e-827e-278611a83c4d.png)

# %% [markdown]
# ![image.png](attachment:0f542f33-e23e-4940-9b08-a2ca4bfd4304.png)

# %% [markdown]
# ![image.png](attachment:81b1e3e9-03f5-4447-9edf-399941a9502a.png)

# %% [markdown]
# ![image.png](attachment:0e62c409-d917-4a08-b0b3-21a6f2bcd1ea.png)

# %% [markdown]
# ![image.png](attachment:f0908358-56a9-46f1-ac5c-07180976c4ed.png)

# %% [markdown]
# ![image.png](attachment:9715bd77-ee70-4433-9dfc-626b23d849e0.png)

# %% [markdown]
# ![image.png](attachment:5a5b9e7e-bc7c-478d-bedd-b03d95b3f3b6.png)

# %% [markdown]
# * variance and coviariance
#
# ![image.png](attachment:a541083c-4c2f-4341-87f1-90e822ae537d.png)

# %% [markdown]
# * covariance matrix
#
# ![image.png](attachment:e0d9d879-30cf-4c1f-9d64-50953aa3f15c.png)

# %% [markdown]
# ![image.png](attachment:4be5877f-3ba7-4fe3-b553-97f4a59aab97.png)

# %% [markdown]
# ![image.png](attachment:83e1b22e-7b86-40e2-b13c-6ec2d9db5c2c.png)

# %% [markdown]
# # eigen values and eigen vectors
#
# ![image.png](attachment:aafde8bc-05cf-4a1f-a81d-9e52065be147.png)

# %% [markdown]
# ![image.png](attachment:2d8b9151-3fe7-4f2b-b3fc-07f6e676fdd3.png)

# %% [markdown]
# ![image.png](attachment:2a8a68ab-7324-482a-a6cc-01c3ebff2957.png)

# %% [markdown]
# ![image.png](attachment:5ca2e08e-4cea-44a9-bfdc-eaa7c87ccb1d.png)

# %% [markdown]
# ![image.png](attachment:a287c7f6-e13b-40cb-a272-701c60e61eea.png)
