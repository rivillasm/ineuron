# %% [markdown]
# # modules for functions

# %%
# !ls
# Out:
# 001_fs_python.ipynb
# 002_fs_python_Functions.ipynb
# 003_fs_ExceptionHandling.ipynb
# 004_fs_Logging.ipynb
# 005_fs_modules.ipynb
# 005_fs_modules.py
# Untitled.ipynb
# Untitled1.ipynb
# readme.md

# %%
import test_modules  # FILE PY CREATED WITH A FUNCTION IN IT, it imports all the function in themoduel

# %%
test_modules.test(5,5)   # using the file as a module and using the funciton within the file.
# Out:
# 10

# %%
test_modules.test4()  # you may need to restart the kernel with jupyter lab
# Out:
# this is my code

# %%
from test_modules import test3  # use this way to import only one of the functions from within the file

# %%
from test_modules import *  # imports all the functions from the module file.

# %%
dir()  # function that list down all method/functions available in  particular modules
# Out:
# ['In',
#  'Out',
#  '_',
#  '_2',
#  '_7',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_exit_code',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'quit',
#  'test',
#  'test1',
#  'test3',
#  'test4',
#  'test_modules']

# %%
open("my_module.py","w")
# Out:
# <_io.TextIOWrapper name='my_module.py' mode='w' encoding='cp1252'>

# %%
import my_module  # import all methods available in the module file

# %%
my_module.

# %% [markdown]
# # pycharm

# %% [markdown]
# ![image.png](attachment:befc7d33-5447-48bb-9faf-eb98aca584a1.png)

# %% [markdown]
# ![image.png](attachment:d944c16b-5c03-4fd5-bf8b-40469eaf67e3.png)

# %% [markdown]
# ![image.png](attachment:5e71ff58-c5f7-447a-be57-6044bdc836c9.png)

# %% [markdown]
# # module inside a package
# ![image.png](attachment:599982b0-3d29-4d8d-891f-ba1bb016a9bc.png)

# %% [markdown]
# * run the function inside the module
# ![image.png](attachment:1cf06522-3df0-429a-ab61-271f3697275a.png)
