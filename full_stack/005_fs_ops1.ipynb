# %% [markdown]
# ![image.png](attachment:64941e50-fa9d-44c5-bb15-d8c9dcb1456e.png)

# %% [markdown]
# # goals of the object oriented programming

# %% [markdown]
# ![image.png](attachment:4ecfa38a-f2a2-46f7-b25b-30b2d3cd51fa.png)

# %% [markdown]
# ![image.png](attachment:5f4cfaa0-2fa0-4321-9006-c94f5ff3fc76.png)

# %% [markdown]
# ![image.png](attachment:f6d0bf86-7895-4546-978c-5b51a5cf06ce.png)

# %% [markdown]
# ![image.png](attachment:10bedb17-8692-4dd3-8483-488fab75827a.png)

# %%
class person:     # empty class
    pass

john_doe = person()              # creates aperson instance called joh_doe
john_doe.name = "mario"          # adds attributes to the instance
john_doe.surname = "rivillas"    # 
john_doe.year_of_birth = 1969

# %%
print(john_doe)

# %%
print(john_doe.name,john_doe.surname,john_doe.year_of_birth)
# Out:
# mario rivillas 1969

# %%
class person:
    company = "ineuron"      # class variable
    
    def __init__(self, name, surname, year_of_birth):  # adds 3 attributes to every object instantiated
        self.name = name                               # instance attributes
        self.surname = surname
        self.year_of_birth = year_ob_birth

# %% [markdown]
# ![image.png](attachment:6a2e41c4-c564-4116-aa73-4fcba27557e2.png)

# %% [markdown]
# ![image.png](attachment:3d0121c6-70ef-439c-97f1-cb94ff8e601a.png)

# %% [markdown]
# ![image.png](attachment:77853143-b417-4d73-9eac-1d39a30fcd80.png)
