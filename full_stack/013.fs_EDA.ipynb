# %% [markdown]
# ![image.png](attachment:1aaae307-f44d-4f2f-a38f-57b7c6c3ae36.png)

# %% [markdown]
# ![image.png](attachment:033b5304-155c-49f6-8f47-999bab17ba1d.png)

# %% [markdown]
# ![image.png](attachment:b3e3ea86-b90f-46c4-bf4c-29ec94fbb39a.png)

# %% [markdown]
# ![image.png](attachment:f79fdadf-08b8-4a3d-83e1-22900defbc66.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt
# %matplotlib inline
import seaborn as sns

# Display all the columns of the dataframes
pd.pandas.set_option("display.max_columns", None)

# %%
dataset = pd.read_csv("D:\\lh_data\\ineuron\\house-prices-advanced-regression-techniques\\train.csv")
dataset
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# ![image.png](attachment:f3473373-00da-4cd2-a06e-04543d20f5f6.png)

# %%
dataset.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
[features for features in dataset.columns]
# Out:
# ['Id',
#  'MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
# ...

# %%
features_na = [features for features in dataset.columns if dataset[features].isnull().sum()>=1]   # list of all features with missing values
features_na
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
features_na_percent = [np.round(dataset[features].isnull().mean(),4) for features in features_na]  # use mean to get percent
features_na_percent
# Out:
# [0.1774,
#  0.9377,
#  0.0055,
#  0.0055,
#  0.0253,
#  0.0253,
#  0.026,
#  0.0253,
#  0.026,
#  0.0007,
#  0.4726,
#  0.0555,
#  0.0555,
#  0.0555,
#  0.0555,
#  0.0555,
#  0.9952,
#  0.8075,
#  0.963]

# %%
dict_features_na = {features: np.round(percent*100,2) for features, percent in zip(features_na, features_na_percent)}  # dictionary
dict_features_na
# Out:
# {'LotFrontage': 17.74,
#  'Alley': 93.77,
#  'MasVnrType': 0.55,
#  'MasVnrArea': 0.55,
#  'BsmtQual': 2.53,
#  'BsmtCond': 2.53,
#  'BsmtExposure': 2.6,
#  'BsmtFinType1': 2.53,
#  'BsmtFinType2': 2.6,
#  'Electrical': 0.07,
#  'FireplaceQu': 47.26,
#  'GarageType': 5.55,
#  'GarageYrBlt': 5.55,
#  'GarageFinish': 5.55,
#  'GarageQual': 5.55,
#  'GarageCond': 5.55,
#  'PoolQC': 99.52,
#  'Fence': 80.75,
#  'MiscFeature': 96.3}

# %%
sns.boxplot(data=dataset.SalePrice)
# Out:
# <AxesSubplot:>

# %%
# plots

data = dataset.copy()

for feature in features_na:
    data[feature] = np.where(data[feature].isnull(),1,0)      # variable where 1 means missing , 0 means ok
    data.groupby(feature)['SalePrice'].median().plot.bar()    # calculate the median in salesprice for the missing/nomissing values
    plt.title(feature)
    plt.show()

# %%
# numerical variables
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
numerical_features = [features for features in dataset.columns if dataset[features].dtypes!="object"]  # filter the object features
numerical_features
# Out:
# ['Id',
#  'MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %%
dataset[numerical_features].head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %%
# Temporal Variables
temporal_features = [feature for feature in numerical_features if "Yr" in feature or "Year" in feature]
temporal_features
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
for feature in temporal_features:
    print(feature, dataset[feature].unique())    # unique values for every feature
# Out:
# YearBuilt [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
# YearRemodAdd [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
# ...

# %%
# find the relation between the saleprice and the tempral features

for i in range(len(temporal_features)):            
                dataset.groupby(temporal_features[i])["SalePrice"].median().plot()
                plt.xlabel(str(temporal_features[i]))
                plt.ylabel("Sale Price")
                plt.show()

# %% [markdown]
# *  The newer the house the more expensive it is

# %%
data = dataset.copy()
for feature in temporal_features:
    if feature!="YrSold":
        data[feature] = data["YrSold"] - data[feature]
        plt.scatter(data[feature], data["SalePrice"])
        plt.xlabel(str(feature))
        plt.ylabel("Sale Price")
        plt.show()

# %% [markdown]
# * Observation = it looks like a power law distribution

# %% [markdown]
# # Numerical Variables - Continuos and Discrete

# %%
numerical_features = [features for features in dataset.columns if dataset[features].dtypes!="object"]  # filter the object features
numerical_features
# Out:
# ['Id',
#  'MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %%
numerical_feature_discrete = [feature for feature in numerical_features if (len(dataset[feature].unique())<=25)]  # if unique values <25 then discrete variable
numerical_feature_discrete
# Out:
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold']

# %%
# find the relation between the saleprice and the tempral features
data = dataset.copy()

for feature in numerical_feature_discrete:            
                data.groupby(feature)["SalePrice"].median().plot.bar()
                plt.xlabel(feature)
                plt.ylabel("Sale Price")
                plt.title(feature.upper())
                plt.show()

# %%
# filter the numerical discrete and the temporal features, outputs only the numerical continuos features
numerical_feature_continuous = [feature for feature in numerical_features if feature not in numerical_feature_discrete+temporal_features ] 
numerical_feature_continuous
# Out:
# ['Id',
#  'LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'SalePrice']

# %%
# use histograms to analyze continuos features
data = dataset.copy()

for feature in numerical_feature_continuous:            
                data[feature].hist(bins=20)
                plt.xlabel(feature)
                plt.ylabel("Count")
                plt.title(feature.upper())
                plt.show()

# %% [markdown]
# # EDA Part II

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(5, 3))
axes[0].plot(x1, y1)
axes[1].plot(x2, y2)
fig.tight_layout()

# %%
# logaritmic transformation from log into normal conversion

data = dataset.copy()

for feature in numerical_feature_continuous:
    if 0 in data[feature].unique():
        pass
    else:
        data[feature] = np.log(data[feature])
        data[feature].hist(bins=20)
        plt.xlabel("Log("+feature+")")
        plt.ylabel("Count")
        plt.title("LOG("+feature.upper()+")")
        plt.show()

# %% [markdown]
# * to plot several paired graphs
#
# ![image.png](attachment:3d82e9eb-d409-4768-9f40-56f934540877.png)

# %%
# logaritmic transformation from log into normal conversion

data = dataset.copy()

for feature in numerical_feature_continuous:
    if 0 in data[feature].unique():
        pass
    else:
        data[feature] = np.log(data[feature])
        plt.scatter(data[feature],data["SalePrice"])
        plt.xlabel("Log("+feature+")")
        plt.ylabel("Count")
        plt.title("LOG("+feature.upper()+")")
        plt.show()

# %% [markdown]
# # OUTLIERS

# %% [markdown]
# ![image.png](attachment:c8675a04-c76a-4b75-9382-434e49c3edcb.png)

# %%
data = dataset.copy()

for feature in numerical_feature_continuous:
    if 0 in data[feature].unique():
        pass
    else:
        data[feature] = np.log(data[feature])
        data.boxplot(column=feature)
        plt.xlabel("Log("+feature+")")
        plt.title("LOG("+feature.upper()+")")
        plt.show()

# %%
sns.histplot(dataset["SalePrice"],kde=True)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Count'>
