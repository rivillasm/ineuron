# %% [markdown]
# # APPLICATION PROGRAMMING INTERFACE

# %% [markdown]
# in pycharm go to file create new project
#
# ![image.png](attachment:256844fa-9c79-41e7-9266-1611ee9df81c.png)

# %% [markdown]
# * install flask if required
#
# ![image.png](attachment:81eb80ee-1c79-4ebf-ae72-68aefe50ef5e.png)

# %% [markdown]
# ![image.png](attachment:d8db802c-74f7-4d99-aeb7-a2e5f56833f9.png)

# %% [markdown]
# # GET
#
# ![image.png](attachment:75c1c915-3fbd-454b-9c9f-c9fb8f313c58.png)

# %% [markdown]
# # POST
#
# ![image.png](attachment:ef309e7f-ae10-45d4-a30a-07730a98fe98.png)

# %% [markdown]
# # my application
# ![image.png](attachment:5939a894-95f6-42e0-958f-1aad9b97c575.png)
#
# * Notice the application is running

# %% [markdown]
# # POSTMAN

# %% [markdown]
# ![image.png](attachment:c6336880-a7b0-49e8-81eb-c5cc339a2b25.png)

# %% [markdown]
# * Set GET/POST and the url
#
# ![image.png](attachment:9bfa529d-593b-42dd-9e24-f6cb4ca4dda2.png)

# %% [markdown]
# * provide the data into the body in the correct format
# * for json make sure to use double quotes
# * make sure the keys used match the keys used in the .py program
#
# ![image.png](attachment:93e74d0c-bfbd-4fd7-8b57-df3af69d0e4a.png)

# %% [markdown]
# * confirmation from pycharm
# * shows the method used and provides 200 as a code meaning success.
#
# ![image.png](attachment:0a72d684-9a12-4515-a6d9-f0cd457f4679.png)

# %% [markdown]
# ![image.png](attachment:33ba8f3c-7ca3-436c-8001-a6e8fc3d2946.png)

# %% [markdown]
# ### Tasks
# ![image.png](attachment:105b9758-5c24-4e9a-9715-525416bb5e22.png)

# %% [markdown]
# # SQLITE

# %%
import csv

message =""" title,author,year 
            The Weirdstone of Brisingamen,Alan Garner,1960 
            Perdido Street Station,China Miéville,2000 
            Thud!,Terry Pratchett,2005 
            The Spellman Files,Lisa Lutz,2007 
            Small Gods,Terry Pratchett,1992 """


# creates a file
with open('books.csv', 'w') as f:  # open the file in the write mode  
    writer = csv.writer(f, delimiter="\n")         # creates the csv writer
    writer.writerow(message.splitlines())          # writes  row to the csv file
    
f.close()

# %%
import sqlite3     # is in the system by default
import csv

try:
    db = sqlite3.connect("books.db")   # creates a .db file to save data in a structured format
                                       # this serves a connection to a local file named .db 
                                       # file can be saved in several places    
    c = db.cursor()                    # creates a pointer
    print("Successfully Connected to SQLite")
    
    # CREATES A TABLE
    c.execute("CREATE TABLE IF NOT EXISTS books(title TEXT, author TEXT, year INT)")  
    db.commit()
    print("SQLite table created")
    
    # Reads a file
    with open("books.csv") as csvfile:
        csvreader = csv.reader(csvfile,delimiter=",")
        next(csvreader)              # This skips the first row of the CSV file with the header.
        print("file successfully read")
        for row in csvreader:
            if(len(row)==3):         # eliminates any line with less than 3 values
                c.execute("INSERT INTO books VALUES (?, ?, ?)", (str(row[0]), str(row[1]), int(row[2])))

    
    c.close()
    
    
except sqlite3.Error as error:
    print("Error while creating a sqlite table", error)

finally:
    if db:
        db.close()
        print("SQlite connection is closed")
# Out:
# Successfully Connected to SQLite
# SQLite table created
# file successfully read
# SQlite connection is closed

# %% [markdown]
# # DB_MONGO

# %%
import pymongo    # is in the system by default
import csv

try:
    client = pymongo.MongoClient("mongodb+srv://rivillasm:rivillasm@cluster0.fcewb.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
    db = client.test
    print(db)   # check for connectivity
    
    client.list_database_names()   # available databases
    
    db = client["books"]          # create a database called books
    collec1 = db["books_collection"]   # creates a collection (table) 
    
    
    
    
    db = sqlite3.connect("books.db")   # creates a .db file to save data in a structured format
                                       # this serves a connection to a local file named .db 
                                       # file can be saved in several places    
    c = db.cursor()                    # creates a pointer
    print("Successfully Connected to SQLite")
    
    # CREATES A TABLE
    c.execute("CREATE TABLE IF NOT EXISTS books(title TEXT, author TEXT, year INT)")  
    db.commit()
    print("SQLite table created")
    
    # Reads a file
    with open("books.csv") as csvfile:
        csvreader = csv.reader(csvfile,delimiter=",")
        next(csvreader)              # This skips the first row of the CSV file with the header.
        print("file successfully read")
        for row in csvreader:
            if(len(row)==3):         # eliminates any line with less than 3 values
                c.execute("INSERT INTO books VALUES (?, ?, ?)", (str(row[0]), str(row[1]), int(row[2])))

    
    c.close()
    
    
except sqlite3.Error as error:
    print("Error while creating a sqlite table", error)

finally:
    if db:
        db.close()
        print("SQlite connection is closed")

# %% [markdown]
# # API II

# %% [markdown]
# * find environments
#
# ![image.png](attachment:0833e507-e798-45fd-8696-5e91c57fc58c.png)

# %% [markdown]
# ![image.png](attachment:4a9e7dd7-1d55-43ec-95be-d8ef0dd3d22d.png)

# %% [markdown]
# ![image.png](attachment:0bb8ee9c-e44a-4c8f-8804-a089a08e8053.png)
#
# * the home page will render the html interface
#
# ![image.png](attachment:8b475b41-9a25-4fb0-a344-59be03084a89.png)
# ![image.png](attachment:b577b46d-44ee-497c-8f83-7224dd35bd4f.png)

# %% [markdown]
# * notice that in /math we are requesting the info from the form from the html page
#
# ![image.png](attachment:496c941e-0ace-4246-bea1-89d3d7d3112b.png)
#
# * index html
#
# ![image.png](attachment:dc7fa06d-ee83-4312-96fe-dc55725d36c2.png)
#
# * results html
#
# ![image.png](attachment:3d4224cd-430c-479b-8372-d94b9e490d6e.png)

# %% [markdown]
# * notice that for postman we are requesting by getting the info from a json format
#
# ![image.png](attachment:3f8edf68-f8f6-44d6-bce6-c6e1b7950f32.png)

# %% [markdown]
# * Postman request
#
# ![image.png](attachment:c9dc8827-d714-45bd-8323-62ef3a2551e9.png)

# %%
def func(a, b=6, c=8):
    print(a,b,c)
    
func(1,2)
# Out:
# 1 2 8

# %%
def func(a, b, c): a = 2; b[0] = 'x'; c[a] = 'y'

# %%
def func(a, *pargs):
    print(a, pargs)
    
func(1, 2,3)
# Out:
# 1 (2, 3)

# %%
def func(a, **kargs):
    print(a, kargs)
    
func(a=1, c=3, b=2)
# Out:
# 1 {'c': 3, 'b': 2}
