# %% [markdown]
# # MONGODB

# %% [markdown]
# * Go to mongodb.com
#
# ![image.png](attachment:f450415f-b959-404a-83d3-e125eac2e3b6.png)
# ![image.png](attachment:d1886767-9907-4aee-a2cb-19a4aa745a13.png)
# ![image.png](attachment:2d3f71e7-31b7-486e-bd28-fd1df8ebe3d5.png)
# ![image.png](attachment:eea8289d-8ed8-49f7-b06d-da77168c0905.png)
#
# * creates a cluster, set username and passw and the connection opptions
#
# ![image.png](attachment:10e2e3e1-3dee-4ae5-b962-8459057eba78.png)
# ![image.png](attachment:bd74bdb9-ae56-43b7-b1f9-df15463463f7.png)
#
# * connecting
#
# ![image.png](attachment:89b70cda-47b6-4118-99da-36ed44f6eb62.png)
# ![image.png](attachment:1bfad83c-5aad-44f4-9dc0-545f2c537d84.png)
#
# * copy the following code to connect to mongodb by using python. use that code in your jupyter lab to connect to mongo atlas cluster0
#
# ![image.png](attachment:2224a57e-94e1-43a4-b5ae-ad72b4a0a261.png)
#
#
# * sing in  (email and pass)
# * this is the inline version of mongo db , is in the cloud

# %% [markdown]
# * you can create more than one cluster if needed
#
# ![image.png](attachment:35572689-9fff-45a4-8a45-50df1b657837.png)

# %% [markdown]
# * or you can create a new project and then creeate a new cluster in that project
#
# ![image.png](attachment:09510377-a4fe-427d-b49f-11d6083a426f.png)

# %%
# !pip install pymongo[srv]

# %%
import pymongo

# %%
# in mongo atlas i have mario_test then ineuron2 then cluster0

client = pymongo.MongoClient("mongodb+srv://rivillasm:rivillasm@cluster0.fcewb.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = client.test
print(db)   # check for connectivity
# Out:
# Database(MongoClient(host=['cluster0-shard-00-01.fcewb.mongodb.net:27017', 'cluster0-shard-00-00.fcewb.mongodb.net:27017', 'cluster0-shard-00-02.fcewb.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-d5zxob-shard-0', ssl=True), 'test')

# %%
client.list_database_names()   # available databases
# Out:
# ['admin', 'local']

# %%
db2 = client["mario"]          # create a database called mario

# %%
client.list_database_names()   # available databases
# Out:
# ['admin', 'local']

# %%
collec1 = db2["ineuron_collection"]   # creates a collection (table)

# %%
dict1={ "name":"mario", 
       "email":"rivillasm@gmail.com", 
       "product":["one_neuron","tech_neuron"],
       "company":"ineuron intelligence private limited"}

# %%
collec1.insert_one(dict1)  # inserting info into a collection

# %% [markdown]
# * now i can see the information within the collection in mongo db, you need to put info there before being able to see it.
# * notice the name mario.ineuron_collection, which is the db name and the collection name
#
# ![image.png](attachment:efdda238-9836-46aa-9bfc-1f3667f050ff.png)
