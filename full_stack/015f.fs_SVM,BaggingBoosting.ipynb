# %% [markdown]
# ![image.png](attachment:df766d98-ecf2-4cad-8d3f-5766f527d710.png)

# %% [markdown]
# ![image.png](attachment:7e56f85f-9b52-44c7-a8b7-f9ca029f69dd.png)

# %% [markdown]
# ![image.png](attachment:d7979ead-8a89-4977-8d6f-32c0487cd03c.png)

# %% [markdown]
# ![image.png](attachment:06a16c18-9065-4b4b-bd13-64e649a6e50f.png)

# %% [markdown]
# ![image.png](attachment:300cfe36-be42-4364-a7c8-f3d96d061f1e.png)

# %% [markdown]
# ![image.png](attachment:11f0431b-4b60-4fe7-b580-d2ba282d1e91.png)
