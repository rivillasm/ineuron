# %% [markdown]
# # REVISE TIME 2H.25M how to test the project
#
# https://learn.ineuron.ai/lesson/17th-Sept-Live-Class-CNN-app-%7C-Creation-of-PrepareBaseModel-stage/63260819952f5620cddc9201/course/Full-Stack-Data-Science-Nov'21-Batch/61b30b40b733d139bc0e7ffb

# %% [markdown]
# # WHIMSICAL.COM - to prepare figures

# %% [markdown]
# * prepare research|st_02.ipynb to test the code to be used for model preparation
#
# ![image.png](attachment:09584ab7-bf6f-4b21-ab37-6e5fae75ef3c.png)
#
# ![image.png](attachment:70abc2af-0dd1-47c0-8133-25b866b44088.png)
#
# ![image.png](attachment:28cb859c-58e8-437e-ac54-72d46d0ec915.png)
#
# ![image.png](attachment:7aea366e-5961-4b7d-b385-43bd5c8e1581.png)
#
# ![image.png](attachment:c2ea6a7d-2493-474c-8084-6453aacb6a28.png)

# %% [markdown]
# * as a result, artefacts are updated
#
# ![image.png](attachment:84bc5d56-247c-493f-92a0-72ace52c946a.png)
#
# and summary created
#
# ![image.png](attachment:800040ab-f2a8-4362-a3c8-75b983ce815a.png)

# %% [markdown]
# * prepare research|st_03.ipynb to test the code to be used for model preparation
#
# ![image.png](attachment:07f8d314-6e42-47c5-a63b-be936a780e50.png)
#
# ![image.png](attachment:d772869f-fddb-47a6-a8b2-cffd692f32f9.png)
#
# ![image.png](attachment:cffc7d25-86e7-4eda-b912-f68ed54adc9f.png)
#
# ![image.png](attachment:8922c0f6-8f84-4aae-9dc9-702c7694544b.png)
#
# as a result the following folders got created
#
# ![image.png](attachment:035a8dfe-a8ae-4ad0-9cfd-f6b005c0fa46.png)

# %% [markdown]
# * prepare research|st_04.ipynb to test the code to be used for model preparation
#
# ![image.png](attachment:a64fb0bb-5fa8-47cc-b17f-e5ce00439f1f.png)
#
# ![image.png](attachment:84a231e2-2696-458a-be10-cd1a2ef36c42.png)
#
# ![image.png](attachment:489e9ad0-e2b5-485d-bfd5-13dec98b5610.png)
#
# ![image.png](attachment:06e9df6e-de00-4fa2-90bc-594170f346f7.png)
#
# ![image.png](attachment:8889ae41-f0b0-40d5-ab55-920e27ed17fc.png)
#
# ![image.png](attachment:13df00af-a669-4455-9ed3-cb5d8e2beca8.png)
#
# ![image.png](attachment:afae2ad9-6a11-4e3c-9994-075a5957b214.png)
#
# * creates the following items
#
# ![image.png](attachment:c7a0f468-8e40-4165-a8e4-c2e63d0eb6bc.png)

# %% [markdown]
# * run the tensor board in the terminal
#
# ![image.png](attachment:845ac7fe-5118-4a83-b5e2-c0fbfbb36c50.png)

# %% [markdown]
# # All the info from st_02.ipynb to st_04.ipynb got updated into the corresponding files
#
# ![image.png](attachment:b7ae3d1c-66cd-43bd-b3a6-5ea34f063a09.png)

# %% [markdown]
# # DVC file
#
# ![image.png](attachment:5802b764-d566-4610-9cd6-59aaa96cc311.png)

# %% [markdown]
# * cmd is the path
# * deps are the depnendencies, keep the identure and the dash in front of it
# * outs are the outputs
#
# dvc allows tracking any changes in the pipeline, if not changes have happened then that specific step will not be recreated.

# %% [markdown]
# * example dcv.yaml for data_ingestion
#
# ![image.png](attachment:4515072d-b521-487d-9fab-e56058f74929.png)
#
# * initializa dvc in the termina
#
# ![image.png](attachment:0ef418d8-e5af-4c12-9130-7ca024223823.png)
#
# * creates the following files
#
# ![image.png](attachment:9024873e-652f-4004-bffa-de67f8974b4b.png)
#
# * run the dvc script by using the command "dvc repro"
#
# ![image.png](attachment:59b40778-0d9b-459f-96b4-4b52ce213ade.png)
#
# * the output will be a file dvc.lock containing all the info of the created files
#
# ![image.png](attachment:8ff51472-caf3-44a9-9941-a91ba436b2fa.png)

# %% [markdown]
# * upload DVC for tracking stages
#
# ![image.png](attachment:ee77e7db-f874-44db-85ca-b9411741d60f.png)

# %% [markdown]
# * you can use DVC to check visually the relation between the stages  "dvc dag"
#
# ![image.png](attachment:431ffd9b-ad7d-4bfb-a38d-9e3044eba5ac.png)
