# %% [markdown]
# ![image.png](attachment:d72e2c7a-b739-414a-a333-71d6411284bd.png)

# %% [markdown]
# ![image.png](attachment:40b19b67-9e76-4227-a530-06718a07e1a2.png)

# %% [markdown]
# ![image.png](attachment:e9494464-f5bd-4930-9d0f-fe9ddbd62d64.png)

# %% [markdown]
# ![image.png](attachment:0b507f7b-f944-4580-ad22-8b11f08dda5e.png)

# %% [markdown]
# ![image.png](attachment:227fceca-303c-49b1-ab48-e51d5396ce47.png)

# %% [markdown]
# ![image.png](attachment:13939e0c-1d5d-4567-9dc2-139765476fea.png)

# %% [markdown]
# ![image.png](attachment:75e9b714-3dfe-4ac8-adb4-acc98e55df96.png)
#
# * Education, qualifiaction, blood type, etc..

# %% [markdown]
# ![image.png](attachment:ad335055-d51f-4bac-8761-b04e8554263e.png)

# %% [markdown]
# ![image.png](attachment:1841643c-305c-404b-b4ec-f33df3c9a547.png)

# %% [markdown]
# ![image.png](attachment:ee726e23-50b0-40c3-94eb-1770dacab555.png)

# %% [markdown]
# ![image.png](attachment:2fd7ca76-549c-420a-bb64-e27117433aec.png)

# %% [markdown]
# ![image.png](attachment:4a9bee74-8cf9-4aac-8f8a-895a1ea5c0cd.png)

# %% [markdown]
# ![image.png](attachment:500446b7-0d64-4681-898c-64b9ccc30b40.png)

# %% [markdown]
# ![image.png](attachment:358f7cb4-7941-4a47-8f81-11ddc75fc083.png)

# %% [markdown]
# ![image.png](attachment:fb2504c5-0138-4267-a437-6e354a78df9d.png)
