# %% [markdown]
# ![image.png](attachment:1110b080-4132-4fab-9914-f1b01c39fda2.png)
#
# ![image.png](attachment:5ab573aa-013c-48ef-9eae-791133942db5.png)
#
# ![image.png](attachment:90515160-51cd-4fec-bcc7-5e5484d8fae2.png)
#
# ![image.png](attachment:a2f74149-23ae-420d-84f0-6c50b9e929f1.png)

# %% [markdown]
# * Scalability - requirements change as companies grow, you may need more space so we need to scale horizontally
# * high availability
#
# ![image.png](attachment:8579f581-c1dd-46f2-8146-eaf5112b822b.png)

# %% [markdown]
# ![image.png](attachment:352fbe29-9ba4-4ba4-9132-abc4a3da1528.png)

# %% [markdown]
# ![image.png](attachment:9068fc81-89c3-4a02-b4d2-212b0604d107.png)

# %% [markdown]
# ![image.png](attachment:c2242525-576a-42e5-8780-68c4ae049088.png)

# %% [markdown]
# ![image.png](attachment:457f6397-0323-400f-9458-b99721bfd65b.png)

# %% [markdown]
# ![image.png](attachment:b5eed0a8-a754-43b4-b37a-b6c80f4dda1e.png)

# %% [markdown]
# ![image.png](attachment:46f5d91d-cddd-46c3-ae8a-e3a65d2e9e94.png)

# %% [markdown]
# * go to datastax.com
# * go to create serverless databses

# %% [markdown]
# ![image.png](attachment:ce2cbc6e-2d4c-415e-90f8-759a1a407cf4.png)

# %%
#!pip install cassandra-driver
# Out:
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\programdata\anaconda3\python.exe -m pip install --upgrade pip' command.
