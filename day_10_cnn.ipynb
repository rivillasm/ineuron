# %% [markdown]
# # CNN REVIEW

# %% [markdown]
# ![image.png](attachment:2f22f12f-95d0-48d9-af61-7cbba85c3f8d.png)

# %% [markdown]
# ![image.png](attachment:6d3520c5-9bac-4307-8d5a-e524d2b861fd.png)

# %% [markdown]
# ![image.png](attachment:189c0fa9-a811-4e96-86ef-b294e99d726a.png)

# %% [markdown]
# ![image.png](attachment:437318a2-29b1-4271-aacf-3d444f0a1460.png)

# %% [markdown]
# ![image.png](attachment:d448b587-7739-45fd-9ba1-6243a995b66c.png)

# %% [markdown]
# ![image.png](attachment:007a8556-83b3-4ea4-9fe0-f193fc60d2a7.png)
