# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %matplotlib inline

# %%
df = pd.DataFrame(np.random.randn(1000), columns=["data"], index=pd.date_range(start='2022/03/26',periods=1000))
df
# Out:
#                 data
# 2022-03-26 -0.906841
# 2022-03-27  2.538840
# 2022-03-28 -0.358985
# 2022-03-29 -0.383672
# 2022-03-30  0.754873
# ...              ...
# 2024-12-15 -0.188929
# 2024-12-16 -0.161784
# 2024-12-17  0.127094
# 2024-12-18  0.382448
# 2024-12-19 -0.568231
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df= pd.read_csv('https://raw.githubusercontent.com/venky14/Machine-Learning-with-Iris-Dataset/master/Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df[["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm","Species"]].plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.loc[5:11,["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm","Species"]].plot(kind="bar",figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.loc[5:11,["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm","Species"]].plot(kind="barh",figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.loc[:,["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm","Species"]].plot(kind="hist",figsize=(20,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.loc[:,["SepalLengthCm"]].plot(kind="hist",orientation='horizontal',figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
df.hist(figsize=(10,10),color="g",alpha=.4)
# Out:
# array([[<AxesSubplot:title={'center':'Id'}>,
#         <AxesSubplot:title={'center':'SepalLengthCm'}>],
#        [<AxesSubplot:title={'center':'SepalWidthCm'}>,
#         <AxesSubplot:title={'center':'PetalLengthCm'}>],
#        [<AxesSubplot:title={'center':'PetalWidthCm'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df.loc[:,["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm","Species"]].plot(figsize=(20,15),kind="box")
# Out:
# <AxesSubplot:>

# %%
df.loc[:,["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm","Species"]].plot(figsize=(20,15),color={"boxes":"g","whiskers":"r"},kind="box")
# Out:
# <AxesSubplot:>

# %%
df.loc[:,["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm","Species"]].plot(kind="area",figsize=(15,15))
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x="SepalLengthCm",y="PetalLengthCm",figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df.plot.scatter(x="SepalLengthCm",y="PetalLengthCm",c="SepalWidthCm",figsize=(10,10),s=80)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df.plot.hexbin(x="SepalLengthCm",y="PetalLengthCm",figsize=(10,10),gridsize=10)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df.drop(columns=["Species","Id"]).iloc[0].plot(kind="pie",figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='0'>

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # PLOTLY

# %%
df= pd.read_csv('https://raw.githubusercontent.com/venky14/Machine-Learning-with-Iris-Dataset/master/Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df1=df.head().copy()
df1
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df1.iplot()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-f4cfec782b16> in <module>()
# ----> 1 df1.iplot()
#
# C:\ProgramData\Anaconda3\lib\site-packages\cufflinks\plotlytools.py in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#    1216 		return iplot(figure,validate=validate,sharing=sharing,filename=filename,
# ...

# %%
df.iplot(x="",y="",mode="markers", kind="scatter")   # scatter plot

# %%
df.iplot(kind="scatter",mode="markers",size=3)   # scatter plot
