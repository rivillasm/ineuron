# %% [markdown]
# # vehicle detection
#
# https://www.youtube.com/watch?v=rzZsQ9STRjc

# %% [markdown]
# ![image.png](attachment:7f1d4d7b-6dd7-4fd8-a6e7-391187419329.png)

# %% [markdown]
# ![image.png](attachment:cdf227ec-abf5-472b-bed1-4d2dc1e149c2.png)
