# %% [markdown]
# # road sign recognition
#
# https://www.youtube.com/watch?v=NyITTecTFZw

# %% [markdown]
# ![image.png](attachment:9a36b4e7-0b55-479e-9b45-6a3e9f6199fb.png)

# %% [markdown]
# ![image.png](attachment:5e0a42ab-e705-4024-be5d-290ae1aaf100.png)

# %%
# !pip install pyqt5
# Out:
# ...
#      ---------------------------------------- 6.8/6.8 MB 29.1 MB/s eta 0:00:00
# ...
#   Using cached PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl (50.1 MB)
# ...
#      ---------------------------------------- 78.4/78.4 kB ? eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.2.2 requires pyqtwebengine<5.13, which is not installed.
# spyder 5.2.2 requires pyqt5<5.13, but you have pyqt5 5.15.9 which is incompatible.

# %%
# !pip install Pillow

# %%
from PyQt5 import QtCore, QtGui, QtWidgets   #GUI toolkit
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os
import xml.etree.ElementTree as ET

data=[]
labels=[]
classes=4
cur_path = os.getcwd()

classs = {1:"Traffic Light", 2:"Stop", 3:"Speedlimit", 4:"Crosswalk"} 

#retrieving images and labels
print("Obtaiing images and its labels......")

# get the data
path = os.path.join(cur_path,"datasets_day21/train/data")
images = os.listdir(path)
#print(images)

for a in images:
    try:
        image = Image.open(path + "\\" + a)
        image = image.resize((30,30))
        image = np.array(image)
        data.append(image)
        labels.append(i)
    except:
        print("error loading image")

print("Dataset Loaded.....")


# get the corresponding labels
tree =ET.parse('006091_02_Harry_Convert.xml')
root = tree.getroot()
root.tag

for product in root:
    print(product.tag, product.attrib)


    for child in product:
        print(child.tag,  child.attrib)
# converting list into numpy arrays
data = np.array(data)
labels = np.array(labels)
# Out:
# Obtaiing images and its labels......
# ...

# %%
import xml.etree.ElementTree as ET

# get the data
path = os.path.join(cur_path,"datasets_day21/train/labels")
xml_files = os.listdir(path)
print(xml_files)

# tree =ET.parse('006091_02_Harry_Convert.xml')
# root = tree.getroot()
# root.tag

# for product in root:
#     print(product.tag, product.attrib)


#     for child in product:
#         print(child.tag,  child.attrib)
# Out:
# ['road0.xml', 'road1.xml', 'road10.xml', 'road100.xml', 'road101.xml', 'road103.xml', 'road104.xml', 'road105.xml', 'road106.xml', 'road107.xml', 'road108.xml', 'road109.xml', 'road11.xml', 'road110.xml', 'road111.xml', 'road112.xml', 'road113.xml', 'road114.xml', 'road115.xml', 'road116.xml', 'road117.xml', 'road118.xml', 'road119.xml', 'road12.xml', 'road120.xml', 'road121.xml', 'road122.xml', 'road123.xml', 'road124.xml', 'road125.xml', 'road126.xml', 'road127.xml', 'road128.xml', 'road129.xml', 'road13.xml', 'road130.xml', 'road131.xml', 'road132.xml', 'road133.xml', 'road134.xml', 'road135.xml', 'road136.xml', 'road137.xml', 'road138.xml', 'road139.xml', 'road14.xml', 'road140.xml', 'road141.xml', 'road142.xml', 'road143.xml', 'road144.xml', 'road145.xml', 'road146.xml', 'road147.xml', 'road148.xml', 'road149.xml', 'road15.xml', 'road150.xml', 'road151.xml', 'road152.xml', 'road153.xml', 'road154.xml', 'road155.xml', 'road156.xml', 'road157.xml', 'road158.xml', 'road159.xml', 'r
# ...
