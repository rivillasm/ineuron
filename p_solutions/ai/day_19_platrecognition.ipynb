# %% [markdown]
# # PLATE RECOGNIZTION
#
# https://www.youtube.com/watch?v=YqoTDxH1dW0

# %% [markdown]
# ![image.png](attachment:26f53f8f-368b-4486-8224-dd2138173bcf.png)

# %% [markdown]
# ![image.png](attachment:68a3e3ed-3028-4163-8a02-518362767feb.png)

# %% [markdown]
# # rivillasm@gmail.com  / 7Nev@eh7   - requires payment

# %% [markdown]
# ![image.png](attachment:93ebfa63-13b3-43ac-bfc0-b39227ff9b66.png)

# %% [markdown]
# ![image.png](attachment:92e9cfdc-b14c-4b06-8051-a81c520df21b.png)
