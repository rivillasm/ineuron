# %% [markdown]
# ![image.png](attachment:1b5bb40a-02a1-41c9-92dc-5615c7d1f957.png)

# %% [markdown]
# ## ADD a table
#
# ![image.png](attachment:00f6c3e2-0bcb-40ed-a593-f3959fdde515.png)

# %% [markdown]
# ## DELETE A TABLE
#
# ![image.png](attachment:51a372ef-3f4a-45af-bbaa-6383c2fb9a19.png)

# %% [markdown]
# ### UPDATE TABLE
#
# ![image.png](attachment:ed84f287-7770-45c1-9180-d0a4c850eaf0.png)

# %% [markdown]
# ## DATA IMPORT
#
# ![image.png](attachment:2e80cc83-267e-4f8f-873f-90a15a5e94ff.png)

# %% [markdown]
# * MANUAL IMPORT
#
# ![image.png](attachment:a0d4d423-595c-4baa-b24f-4ebf190f4793.png)

# %% [markdown]
# ![image.png](attachment:d5d59f87-3d01-40f5-b224-c246f03c86fd.png)
#
# ![image.png](attachment:333119f5-e004-441f-8d1b-f37f13ad7e7d.png)
#
# ![image.png](attachment:8d15fc05-1700-4475-9f5e-9871c91f0f07.png)
#
# ![image.png](attachment:3e239bec-8187-493b-bafa-900f0685f6d5.png)
#
# ![image.png](attachment:1a5b6d32-eea3-4876-b239-20202dc6da87.png)

# %% [markdown]
# * EXAMPLE DATA TO IMPORT
#
# ![image.png](attachment:a0682f05-2c4e-41ae-b477-5509403a1d88.png)

# %% [markdown]
# * you can use also your existing sql file
#
# ![image.png](attachment:81fbdbf6-2ac2-4a21-bad0-e5971a04d7ab.png)
