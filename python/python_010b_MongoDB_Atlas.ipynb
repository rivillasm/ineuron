# %% [markdown]
# ## 19.3.3 MongoDB Atlas
#
# * Atlas is a mongoDB service on cloud. It uses AWS, Azure and GCP cloud services to cater developers all around the globe for managing mongoDB databases.
# * Its a globally available cloud database service for all kinds of modern applications.
# * Visit [ATLAS HOMEPAGE](https://www.mongodb.com/cloud/atlas) for more details.
#
#
# Lets see how to utilize this services -

# %% [markdown]
# ### 19.3.3.1 Login or SignUp
#
# * Signup to your monngoDB atlas account at [here](https://account.mongodb.com/account/login)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Now you have to connect from your local machine to Atlas:
# * Click on connect and then on Allow Access from Anywhere

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Add ip address
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Select the python application and the version
# * do not forget to copy the driver code example
#
# ![image.png](attachment:image.png)
#
#
# client = pymongo.MongoClient("mongodb+srv://rivillasm:<password>@cluster1.n6fsv.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
# db = client.test
#
# Set the user id(rivillasm) and the passw of the database (not the mongodb) and the name of the database, in this case myFirstDatabase
#
# client = pymongo.MongoClient("mongodb+srv://rivillasm:7nevaeh7@cluster1.n6fsv.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
# db = client.test

# %% [markdown]
# > **NOTE**: If you get a DNS error then install the below python package -
# ```
# pip install pymongo[srv]
# ```
#
# > **NOTE**: Always verif your password and userName as well.
#
# > **NOTE**: Also Verify that whether you have given read write permission to the present user or not.

# %%
import pymongo

# %%
pymongo.version
# Out:
# '3.12.1'

# %%
import platform
print(platform.python_version())
# Out:
# 3.6.5

# %%
# test connection

client = pymongo.MongoClient("mongodb+srv://rivillasm:7nevaeh7@cluster1.n6fsv.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
client
# Out:
# MongoClient(host=['cluster1-shard-00-02.n6fsv.mongodb.net:27017', 'cluster1-shard-00-01.n6fsv.mongodb.net:27017', 'cluster1-shard-00-00.n6fsv.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-107c30-shard-0', ssl=True)

# %% [markdown]
# > **NOTE**:
# * *you can also connect from your mongo local to your mongo atlas(cloud), for this go to monbo local and connect and put the cloud URL above*

# %% [markdown]
# ### FINAL TEST

# %%
import pymongo

USR = "iNeuron_TEST" # User created by us

# Auto Generated Password or Password set by You
# Update according to your set password for autogenerated password
PWD = "YoUr__PassWord" 

DB_NAME = "iNeuron_AI" # Specifiy a Database Name

# Connection URL
CONNECTION_URL = f"mongodb+srv://rivillasm:7nevaeh7@cluster1.n6fsv.mongodb.net/myFirstDatabase?retryWrites=true&w=majority"

# Establish a connection with mongoDB
client = pymongo.MongoClient(CONNECTION_URL)

# Create a DB
dataBase = client[DB_NAME]

# Create a Collection Name
COLLECTION_NAME = "iNeuron_Products"
collection = dataBase[COLLECTION_NAME]

# Create a List of Records
list_of_records = [
    {'companyName': 'iNeuron',
     'product': 'Affordable AI',
     'courseOffered': 'Machine Learning with Deployment'},
    
    {'companyName': 'iNeuron',
     'product': 'Affordable AI',
     'courseOffered': 'Deep Learning for NLP and Computer vision'},
    
    {'companyName': 'iNeuron',
     'product': 'Master Program',
     'courseOffered': 'Data Science Masters Program'}
]

# insert above records in the collection
rec = collection.insert_many(list_of_records)

# Lets Verify all the record at once present in the record with all the fields
all_record = collection.find()

for idx, record in enumerate(all_record):
    print(f"{idx}: {record}")
# Out:
# 0: {'_id': ObjectId('619d78e16ebbc0346cb349ef'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
# 1: {'_id': ObjectId('619d78e16ebbc0346cb349f0'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
# 2: {'_id': ObjectId('619d78e16ebbc0346cb349f1'), 'companyName': 'iNeuron', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}

# %% [markdown]
# ### database and collection with the records was created, can be seen in the cloud
#
# ![image.png](attachment:image.png)
