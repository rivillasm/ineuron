# %% [markdown]
# # TIMESERIES

# %% [markdown]
# ![image.png](attachment:c2ed73c9-9c8e-4751-a71d-30a51708d094.png)

# %% [markdown]
# ![image.png](attachment:98f989ce-9960-4993-86f5-8b46b3f35625.png)

# %% [markdown]
# ![image.png](attachment:e78959f0-1dd8-409b-b759-21032555057a.png)

# %% [markdown]
# ![image.png](attachment:29572942-0d51-4bd7-8700-d8cae6949741.png)

# %% [markdown]
# ![image.png](attachment:3c3afcec-ae50-476c-8728-61d5fdae2de7.png)

# %% [markdown]
# ![image.png](attachment:15756ca0-c05b-43e9-9631-0c2bae032196.png)

# %% [markdown]
# ![image.png](attachment:1a0ec295-ebc6-4c9a-9d42-997a0ea35bc8.png)

# %% [markdown]
# ![image.png](attachment:95486bbc-c133-4160-af0b-248fa58776f3.png)

# %% [markdown]
# ![image.png](attachment:49696953-8d20-4ef7-8bfd-4c7f5dc9412e.png)

# %% [markdown]
# ![image.png](attachment:15b4d74f-4184-47e5-b61a-935050334e1f.png)

# %% [markdown]
# ![image.png](attachment:79b2fc6d-d11f-42bc-a9da-c3d40e92cc96.png)

# %% [markdown]
# ![image.png](attachment:29dc1eb8-8144-4d94-af87-d32365952ffc.png)

# %% [markdown]
# ![image.png](attachment:b528ec3e-53d1-4623-af36-2b599d41cc58.png)
