# %% [markdown]
# # MACHINE LEARNING INTRO

# %% [markdown]
# ![image.png](attachment:35ba37eb-fdfa-4c35-8813-f8d93d23ec15.png)

# %% [markdown]
# ![image.png](attachment:c0b9b24e-9d0b-44aa-b29c-dbd8dfc2c032.png)

# %% [markdown]
# ![image.png](attachment:4938236c-8bc2-42cb-a979-349678ad800e.png)

# %% [markdown]
# ![image.png](attachment:31924dd6-dca0-41d4-b08d-e06d110d1bf1.png)

# %% [markdown]
# ![image.png](attachment:a9335588-3689-483a-9e9f-547e70cfd99c.png)

# %% [markdown]
# ![image.png](attachment:cd7d2bee-bd0d-44ae-ba7b-50d9c047fcc1.png)

# %% [markdown]
# ![image.png](attachment:7486dfe3-7cb1-471e-b15a-9743e7760b2a.png)

# %% [markdown]
# ![image.png](attachment:f1ac3522-9dc5-4c32-896b-e0357c278cae.png)

# %% [markdown]
# ![image.png](attachment:aa24c1ba-a98c-4d09-9990-2b8adafe6648.png)

# %% [markdown]
# * supervised ML- you provide the output
# * unsupervised ML- create clustes
# * semi supervised (supervised and unsupervised) ML - the data is provided in groups (unsupervised) and then apply a supervised ML

# %% [markdown]
# ![image.png](attachment:d61999e5-e63d-4698-9dd9-d4ce69fc1857.png)

# %% [markdown]
# ![image.png](attachment:79630151-3f12-4eb0-a616-d2178a87d2af.png)

# %% [markdown]
# ![image.png](attachment:81e7f738-8614-4fcf-84da-e0039639a989.png)
