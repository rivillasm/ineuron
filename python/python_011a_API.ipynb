# %% [markdown]
# # API - from an HTML

# %% [markdown]
# * opening an existing project
# * right on the project folder and go to python interpreter
# ![image.png](attachment:f3188aec-8980-4195-99d9-5f33aa9c8c56.png)

# %% [markdown]
# * add an interpreter
# * select conda environment
# ![image.png](attachment:84812330-1413-4e53-a235-9eab3bea3fdd.png)

# %% [markdown]
# * click on apply and ok
# ![image.png](attachment:ef8b1708-55e0-4052-b146-86ed9b052d2c.png)

# %% [markdown]
# * run pip install flash to remove the import error
# ![image.png](attachment:edb90743-7421-4e35-ae4b-383d9d880d05.png)

# %% [markdown]
# * right click and run the app
# ![image.png](attachment:27aa23c7-54e9-433f-bfc2-55475e1e9f3c.png)

# %% [markdown]
# * by clicking on the link, you end up in an html window
# ![image.png](attachment:91ff574f-bc5b-4897-bec4-daa2848415c9.png)
