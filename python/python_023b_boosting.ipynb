# %% [markdown]
# ![image.png](attachment:5e3dc72c-b0dc-4d68-9dad-59204cc19437.png)

# %% [markdown]
# # Ada Boost
#
# * initial weight assignment, all get the same value
#
# * create a Decision tree for the residual
#
# * find the say of the tree based on the total error
#
# * assign the new weight values to every row
#
#
#
# ![image.png](attachment:18adcce6-733d-40d2-ace2-7c3bd535db3e.png)
#
# * normalize the new weights
#
# ![image.png](attachment:6b09d55a-1750-4bf9-843f-01fcb51cced7.png)
#
# * create buckets to select the new dataset
#
# ![image.png](attachment:9435c984-3ffd-49a1-8b04-750b3e2e02ef.png)
#
# * select new dataset, by getting random values and seeing where in the buckets it falls
#
# ![image.png](attachment:4a18442b-9a89-4fb4-b9e9-a9817010e22d.png)

# %% [markdown]
# # again explanation
#
# ![image.png](attachment:cdd816c6-98ce-4f9d-8ebc-db83e4ed5165.png)
#
# ![image.png](attachment:6115f42a-7599-4193-b4b3-f680986222d5.png)
#
# ![image.png](attachment:e8a93eab-23a7-4cb4-9bd0-37fcf4fdf4c4.png)

# %% [markdown]
# ![image.png](attachment:a34affff-b439-4b6d-ba9b-57fa433835be.png)
