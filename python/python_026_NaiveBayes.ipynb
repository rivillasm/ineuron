# %% [markdown]
# ![image.png](attachment:697a1f93-a5ff-4e79-b890-0d0a1e813c71.png)

# %% [markdown]
# * Naive ML is a probabilistic approach for categorical and text data (CLASSIFICATION)
#
# ![image.png](attachment:97fa0bfa-fc6f-4f8e-aa36-04eb5fa556ef.png)

# %% [markdown]
# ![image.png](attachment:41383c66-1a4c-456d-beef-546a126c08d1.png)

# %% [markdown]
# ![image.png](attachment:7db42aad-d677-413e-9aa1-1736a8ea2780.png)

# %% [markdown]
# ![image.png](attachment:30761490-be86-4779-a420-290c6bd70e75.png)

# %% [markdown]
# ![image.png](attachment:264e2004-32dd-47c2-bcfe-dca392897b64.png)

# %% [markdown]
# * SO FOR DEPENDENT(conditioned) EVENTS THE PROBABILITIES P(A&B) is THE P(A)*P(B|A)

# %% [markdown]
# ![image.png](attachment:9d3c49e2-99c5-47ec-81d3-88fc4b3e9a69.png)

# %% [markdown]
# ![image.png](attachment:a2556d5c-f438-4e6e-8c9a-140f4fbd0886.png)

# %% [markdown]
# ![image.png](attachment:0b75e9d3-c573-4264-b949-83345f211eb1.png)

# %% [markdown]
# ![image.png](attachment:cd7778bc-8a3f-44e8-ab2f-ad592b3bc6ea.png)

# %% [markdown]
# ![image.png](attachment:8681d1d5-82c5-4535-87e0-363047cd7d93.png)

# %% [markdown]
# * for independent events SUCH as TAILS and HEADS
#          P(H and T) = P(T and H), therefore
#
# ![image.png](attachment:78663047-fb15-472b-886e-34ec96c0bab1.png)

# %% [markdown]
# ![image.png](attachment:8b7c86c1-495c-45aa-9c90-ee8edc7f3ca7.png)

# %% [markdown]
# ![image.png](attachment:8839b591-bf05-4eca-9963-9f682f1192b1.png)

# %% [markdown]
# ![image.png](attachment:27125c8b-5e25-4510-a719-b376ba133260.png)

# %% [markdown]
# ![image.png](attachment:0c8abf75-58d8-44f2-b1a2-6637405b8ae7.png)

# %% [markdown]
# ![image.png](attachment:6d325a75-3bae-4752-acfd-3914d9bb6a6c.png)

# %% [markdown]
# ![image.png](attachment:a7a2477d-c9e5-4885-bff4-a9f35dcdc097.png)

# %% [markdown]
# ![image.png](attachment:660a2f8c-854c-4101-b152-09522d417f18.png)
