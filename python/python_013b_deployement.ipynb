# %% [markdown]
# # DEPLOYMENT

# %% [markdown]
# * Local machine with all the libraries and applications
# * cloud provider, a server with the same libraries and applications (HEROKU cloud in this case, 500MB machine)
# * url to map the ipadress of the cloud provider server
#
# * it needs to be installed:  git bash and heroku cli

# %% [markdown]
# * Go to the directory where you have your project for deployment " C:\Users\rivil\DataCampINeuron\Deployment\FlipkratScrappingProject"
#
# * start git , command "git init"

# %% [markdown]
# ![image.png](attachment:66dacc59-c990-4575-a74c-e6b4b9f83654.png)

# %% [markdown]
# * git add .  " to select all the files to be commited "
# ![image.png](attachment:34488fb6-e5f4-400c-a239-ad7622a2e080.png)

# %% [markdown]
# * if required you can ignore some files/directories so git init does not track them up
# ![image.png](attachment:117cf30d-be6b-46a4-936a-643144cd9b9b.png)

# %% [markdown]
# * commit  - all tracked files will be committed
# ![image.png](attachment:aef99ae3-b514-45c5-abe4-db47f3cc57aa.png)

# %% [markdown]
# * see the log of the committments:
# ![image.png](attachment:c787cd52-b02a-45be-95b2-386c63c43f5c.png)

# %% [markdown]
# * craete a runtime.txt file
# ![image.png](attachment:7a63b557-80d9-42dd-a424-cba884933314.png)

# %% [markdown]
# ![image.png](attachment:82d3fcda-4bcc-42f2-afa1-585c019dabe9.png)

# %% [markdown]
# * add the program in the existing requirements.txt file  - specifying we want to use this in a web application specifically for linux machines
#
# ![image.png](attachment:3eafc590-adec-48d9-a823-c74c20e213b4.png)

# %% [markdown]
# * in the procfile (ONLY REQUIRED FOR HEROKU) file you can see the name of the library that was added .
# ![image.png](attachment:94eecce7-15de-48aa-a519-1e5ef7dd5335.png)

# %% [markdown]
# * the app is the name you set when using flask

# %% [markdown]
# ![image.png](attachment:3175422a-0585-448d-b933-6d81815a19fc.png)

# %% [markdown]
# * at HEROKU, craete a new app
# ![image.png](attachment:5b5a9dd8-b710-43f4-9c68-11906a852f4e.png)

# %% [markdown]
# * go to settings
# ![image.png](attachment:0c115035-51b2-42f3-8353-94336b284087.png)

# %% [markdown]
# * you want to config variables
# ![image.png](attachment:eb5890fe-06cf-4fdc-bea5-489280eac3d1.png)

# %% [markdown]
# * add the following variables:
# ![image.png](attachment:0b0f2e4d-54d5-4082-8d4c-2ee51ae31154.png)

# %% [markdown]
# ![image.png](attachment:35efb442-400a-4ff8-9407-d959a654c91d.png)

# %% [markdown]
# * Open application
# ![image.png](attachment:bfdaf66d-3e58-4bda-9d39-f8cd62b1a96a.png)

# %% [markdown]
# * add buildpacks python
# ![image.png](attachment:af6cdb96-05a2-4b53-b425-185a6580f57d.png)

# %% [markdown]
# ![image.png](attachment:5ddd31dc-a9e5-4005-8c68-45a17f903abd.png)

# %% [markdown]
# ![image.png](attachment:01c9b0ae-455a-427f-8a4a-3d129b7d4339.png)

# %% [markdown]
# ![image.png](attachment:66d8d09f-bae9-41e8-9198-81fff7b5512d.png)

# %% [markdown]
# ![image.png](attachment:ee9f5784-78c3-4474-be22-f32e006bdba0.png)

# %% [markdown]
# * see all the buildpacks added
#
# ![image.png](attachment:9da1a09e-85bf-43cf-b30d-3cb5a84b64b5.png)

# %% [markdown]
# * at the terminal, make sure you added and committed the new changes  (updated the rquirements.txt and added the runtime.txt file)
# ![image.png](attachment:2d61a066-7029-4c54-89ad-32bf0a955b89.png)

# %% [markdown]
# * at the terminal, log into heroku and provide the email(rivillasm@gmail.com) and passw(7nevaeh7*) for the account
# ![image.png](attachment:419b2cfd-00b9-4a62-a640-63014543a904.png)

# %% [markdown]
# * in order to run git remote, we need to go to the DEPLOY tab at HEROKU and copy the corresponding command:
#
# ![image.png](attachment:8a8d7197-0f7d-481f-a976-98bc17e6370c.png)

# %% [markdown]
# * At the terminal, run the command, creates a new repository
# ![image.png](attachment:34b57209-ac99-4e43-8f54-8d5d3845fee6.png)

# %% [markdown]
# * For deployment: - run the command
#
# ![image.png](attachment:0dd10062-c491-4bf3-aa1d-2dfc2f37bf66.png)
#
# * this will save the code and install all the dependencies/libraries in HEROKU for deployment

# %% [markdown]
# ![image.png](attachment:b1cd38f2-4671-4eaf-ac09-cf937345d6ea.png)

# %% [markdown]
# ![image.png](attachment:a21fbefc-6e4f-4357-bd2d-d8586f34adc9.png)

# %% [markdown]
# * you can check the process from the HEROKU platform as well by looking at the VIEW LOGS
#
# ![image.png](attachment:b5d794bb-dd23-458e-b337-db9ae52e17e8.png)

# %% [markdown]
# ![image.png](attachment:157529f3-372e-4867-9b1a-2fb2c523fa6b.png)

# %% [markdown]
# * Once build OPEN APP to access the application
# ![image.png](attachment:f536b163-d13c-4df2-ba5f-769287c978f5.png)

# %% [markdown]
# ![image.png](attachment:c04118d8-4a08-41a5-8a93-eb8176dd4178.png)
