# %% [markdown]
# # Architecture

# %% [markdown]
# ![image.png](attachment:a8c2bc43-5135-4be1-a790-adaf620d7a25.png)

# %% [markdown]
# # System Setup

# %% [markdown]
# * open in pycharm
# ![image.png](attachment:91802b74-7398-4d24-91ef-448da33f63fd.png)

# %% [markdown]
# ![image.png](attachment:8396671f-fe17-411d-aaf0-097403dba1f8.png)

# %% [markdown]
# ## Create a virtual environment for the project
#
# * go to File | Settings | project:...  | python interpreter  | right corner item add
#
# ![image.png](attachment:d6f68077-d986-4d3e-9ee2-cb1b129b0349.png)

# %% [markdown]
# * Use the Conda Environment to create a new environment. notice the given name inside the anaconda3 environments
#
# ![image.png](attachment:5227ee6a-de0f-49eb-bf69-28f0a8d74bae.png)

# %% [markdown]
# * once the environment is created click Apply and then OK
#
# ![image.png](attachment:8dd4c751-9180-4efe-b30a-e1ece30de703.png)

# %% [markdown]
# ## INSTALL libaries required for the application
#
# * this are the ones given:
#
# ![image.png](attachment:597d2d79-a925-4ee6-b10b-8e839f0fed0d.png)

# %% [markdown]
# * now we have to add the lib within the rquirements.txt file
#
# ![image.png](attachment:4f357d43-dc8f-4b93-b96b-7c8ed6993302.png)

# %% [markdown]
# ![image.png](attachment:e100735d-2dc3-4cdb-a525-1ce4cc55d686.png)

# %% [markdown]
# ![image.png](attachment:189b0bee-cd74-434d-b8ed-c0e6289817fd.png)

# %% [markdown]
# * Run the applitacion main file  "app.py"
#
# ![image.png](attachment:85c7a189-577e-4bdc-99fb-991eda0703e0.png)

# %% [markdown]
# * after running ,check the TERMINAL and then copy paste the URL into a webbrowser
#
# ![image.png](attachment:5fae3692-9bfd-41e7-9cfa-bdcc8ec1e675.png)

# %% [markdown]
# ![image.png](attachment:15cd6e9a-81fc-4626-be96-178b9ac2ca14.png)

# %% [markdown]
# ![image.png](attachment:a2862421-1f69-4d45-a368-26918b2c0e09.png)

# %% [markdown]
# * $Note$: we are accessing the application i have in my local machine from an internet browser. at the end we need to deploy it to the cloud!!

# %% [markdown]
# ## Deploy in HEROKU

# %% [markdown]
# * to to https://id.heroku.com/login   with rivillasm@gmail.com  and pass: 7.......
#
# ![image.png](attachment:cc5ba641-9fc5-47b9-b9a6-b32c75c90399.png)

# %% [markdown]
# ![image.png](attachment:137d0adc-63fc-4fe4-b6ee-5414be285b05.png)

# %% [markdown]
# * This assumes you have git in your system
#
# ![image.png](attachment:765d7715-b730-4301-938d-46f38996494e.png)

# %% [markdown]
# * create a file called Procfile without any extension inside your project directory, you can use jupyter lab if needed
#
# * app is the name of the file you want to run in your application, in this case "app.py".  gunicorn is just a linux server name
#
# ![image.png](attachment:2278b455-7eb9-441c-a7f0-3c6a9594764b.png)

# %% [markdown]
# * create a file called reuntime.txt inside your project directory, you can use jupyter lab if needed
#
# ![image.png](attachment:52022980-444b-4121-8fdb-dd9ea7394389.png)

# %% [markdown]
# * if Herocu already installed, then open a command prompt CMD

# %% [markdown]
# ## Start deployment

# %% [markdown]
# ![image.png](attachment:1715b6f4-041f-465a-90d1-bd2d498fc1b3.png)
#
# * then go to the project location
#
# ![image.png](attachment:71e9078c-517c-4aae-a2b5-137411451483.png)

# %% [markdown]
# * Initialize the repository git
#
# ![image.png](attachment:fc85df90-c90f-4a50-bc46-87a7dccdbbeb.png)

# %% [markdown]
# * get the remote access of that repository
#
# ![image.png](attachment:e890d447-7c87-4913-ba09-dc5ccafc4a54.png)

# %% [markdown]
# * add files there
#
# ![image.png](attachment:4e9e294b-8dab-4ccb-953d-2c523bbb29de.png)

# %% [markdown]
# * commit
#
# ![image.png](attachment:f6ab8672-55d8-4817-93cc-4cb0411d9291.png)

# %% [markdown]
# * push
#
# ![image.png](attachment:750b4347-033b-4c0a-ae47-34fe7d81aa6e.png)

# %% [markdown]
# * use the url to access the model:  https://grescorepredict-mr-lr.herokuapp.com/
#
# ![image.png](attachment:3cf0dad5-ffa0-4ba6-ac6a-f97b3e5c618a.png)

# %% [markdown]
# ![image.png](attachment:ec220b48-aad8-4c37-bdd5-be36641ead54.png)
