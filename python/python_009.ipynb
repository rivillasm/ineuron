# %% [markdown]
# # Data Visualization

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline    # to display in your notebook

# %%
from numpy.random import randn, randint, uniform, sample

# %%
df = pd.DataFrame(randn(1000), index=pd.date_range('2019-06-07', periods = 1000), columns =['Value'])
ts = pd.Series(randn(1000), index = pd.date_range('2019-06-07', periods = 1000))

# %%
df.head()
# Out:
#                Value
# 2019-06-07  2.314338
# 2019-06-08 -0.268378
# 2019-06-09  0.628118
# 2019-06-10 -2.442613
# 2019-06-11 -0.122849

# %%
ts
# Out:
# 2019-06-07    0.363095
# 2019-06-08    0.479900
# 2019-06-09    0.998701
# 2019-06-10   -0.784646
# 2019-06-11   -1.001938
#                 ...
# 2022-02-26   -0.439769
# 2022-02-27   -0.993795
# 2022-02-28   -1.004582
# 2022-03-01    0.059458
# 2022-03-02   -1.456888
# Freq: D, Length: 1000, dtype: float64

# %%
df.Value.cumsum()
# Out:
# 2019-06-07     2.314338
# 2019-06-08     2.045959
# 2019-06-09     2.674078
# 2019-06-10     0.231465
# 2019-06-11     0.108616
#                 ...
# 2022-02-26    45.918329
# 2022-02-27    46.068672
# 2022-02-28    45.532625
# 2022-03-01    44.755421
# 2022-03-02    45.249832
# Freq: D, Name: Value, Length: 1000, dtype: float64

# %%
ts.plot(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
ts = ts.cumsum()
ts.plot()
# Out:
# <AxesSubplot:>

# %%
plt.plot(ts)

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
plt.plot(df.Value)

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
ts.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df = iris.drop(['species'],axis=1)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.iloc[0].plot(kind='bar')  # first row
# Out:
# <AxesSubplot:>

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.pclass.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(randn(10,4),columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  1.030742  0.329590  0.206623  1.127722
# 1 -0.321684  1.350000  0.315611 -0.954998
# 2 -0.212933  0.940459 -0.677753 -1.033056
# 3 -1.535757 -1.790823  0.096965  0.275714
# 4 -1.540168 -0.555359 -0.774240 -0.497690
# 5  2.420390  0.495120 -0.457594  1.182806
# 6  0.289517 -1.623475 -0.206331  1.234643
# 7 -1.322778 -0.331610  0.818043  0.102882
# 8  1.225247  0.185860 -0.605494 -0.232525
# 9 -0.700649 -0.077172  1.261599  0.703428

# %%
df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.barh()
# Out:
# <AxesSubplot:>

# %%
iris.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist',bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist',stacked=True, bins=100)    # stacks the different values, shows all the data
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.sepal_width.plot(kind='hist', stacked=True, bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.sepal_width.diff().plot(kind='hist', stacked=True, bins=50)   # difference against previous row(s)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.sepal_width.head()
# Out:
# 0    3.5
# 1    3.0
# 2    3.2
# 3    3.1
# 4    3.6
# Name: sepal_width, dtype: float64

# %%
iris.sepal_width.diff().head()
# Out:
# 0    NaN
# 1   -0.5
# 2    0.2
# 3   -0.1
# 4    0.5
# Name: sepal_width, dtype: float64

# %%
df
# Out:
#           a         b         c         d
# 0  1.030742  0.329590  0.206623  1.127722
# 1 -0.321684  1.350000  0.315611 -0.954998
# 2 -0.212933  0.940459 -0.677753 -1.033056
# 3 -1.535757 -1.790823  0.096965  0.275714
# 4 -1.540168 -0.555359 -0.774240 -0.497690
# 5  2.420390  0.495120 -0.457594  1.182806
# 6  0.289517 -1.623475 -0.206331  1.234643
# 7 -1.322778 -0.331610  0.818043  0.102882
# 8  1.225247  0.185860 -0.605494 -0.232525
# 9 -0.700649 -0.077172  1.261599  0.703428

# %%
df.diff().hist(color='b',alpha=0.5, figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'a'}>,
#         <AxesSubplot:title={'center':'b'}>],
#        [<AxesSubplot:title={'center':'c'}>,
#         <AxesSubplot:title={'center':'d'}>]], dtype=object)

# %%
iris.plot.scatter(x='sepal_length',y='petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
iris.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
iris.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width',s=100)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
iris.plot.hexbin(x='sepal_length',y='petal_length',C='sepal_width', gridsize=10)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df = iris.iloc[0,:4]
df
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: object

# %%
df.plot.pie(figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='0'>

# %%
df = iris.iloc[0:3,:4].T
df
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
df.plot.pie(subplots=True, figsize=(20,20))
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
df.plot.pie(subplots=True, figsize=(20,20), fontsize=25, autopct='%.2f')
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(iris, figsize=(8,8), diagonal='kde', color='b')
plt.show()

# %%
iris.sepal_length.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
from pandas.plotting import andrews_curves

# %%
df = iris.iloc[:,:4]
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
andrews_curves(df, 'sepal_width')
# Out:
# <AxesSubplot:>

# %%
df.sepal_length.plot(style='r--',label='Series', legend=True)
# Out:
# <AxesSubplot:>
