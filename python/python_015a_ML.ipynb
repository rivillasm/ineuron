# %% [markdown]
# ![image.png](attachment:c15b705b-94fc-4d94-90b3-205bb57dadbc.png)

# %% [markdown]
# ![image.png](attachment:44777f62-e2b6-4556-ac59-30433a6b9e00.png)

# %% [markdown]
# ![image.png](attachment:b4a82c53-469b-476f-9ac1-5d5af010ab0c.png)

# %% [markdown]
# * TYPES OF LINEAR REGRESSION
# ![image.png](attachment:7f5524f2-291f-4942-a93f-82334d6f8d72.png)

# %% [markdown]
# # ML PIPELINE
# ![image.png](attachment:0afd26bf-38d6-4f9b-9504-977d9c1449bb.png)

# %% [markdown]
# ![image.png](attachment:dcec6db2-73cd-4b08-ad63-98337e924399.png)

# %% [markdown]
# ![image.png](attachment:23aee4fa-f0a3-4eb7-8f24-cab4ecc2586b.png)

# %% [markdown]
# ![image.png](attachment:27eedf3c-4455-4a90-8494-3c81232c4911.png)

# %% [markdown]
# ![image.png](attachment:846c0d4b-0824-4c56-ad97-9b2b61ec247e.png)

# %% [markdown]
# # regression problem:
# ![image.png](attachment:738f3de7-a403-4573-b97c-9490340b9b0f.png)
#
# * the goal is to get the best fit line  "y = mx + c" as the end goal

# %% [markdown]
# ![image.png](attachment:9c6f6cb4-a35f-4db0-8917-dff1f9210944.png)
# * first perform the calculation
# * check the error = result(prediction) - actual, this is the error.
# * optimize the parameters m and c from y=mx+c so that the error is minimized, this way we obtained the best fit line OLS "ordinary lease squeare"

# %% [markdown]
# ![image.png](attachment:ac271f35-1cfb-4332-bbe7-16e9702f3d56.png)

# %% [markdown]
# ![image.png](attachment:29a72220-5591-436b-b031-93ca7d9e1c0e.png)

# %% [markdown]
# * eucledian distance:
# ![image.png](attachment:7c508264-de48-4e23-a209-fde81328bd3a.png)

# %% [markdown]
# ![image.png](attachment:85e7af24-ff99-4289-9f5d-aac51e078d68.png)

# %% [markdown]
# * m = rate of change
# ![image.png](attachment:f8974177-1c72-4b40-b98b-048b42599548.png)

# %% [markdown]
# ![image.png](attachment:8bd4d505-2456-44f2-a3a0-a38eff87257a.png)

# %% [markdown]
# * point slope formula
# ![image.png](attachment:6a317324-68a5-4c86-bbe1-9178b58da0aa.png)
