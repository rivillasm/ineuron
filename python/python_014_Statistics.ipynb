# %% [markdown]
# # Statistics - the science of collecting, organizing and analyzing data.

# %% [markdown]
# ![image.png](attachment:fb2c0c4a-b03a-402c-9cb8-34a6c930c572.png)

# %% [markdown]
# ![image.png](attachment:61f8322e-0e14-4131-b600-3c7423a59066.png)

# %% [markdown]
# Example - Descriptive - summarization of data
# ![image.png](attachment:fb97fe66-33b0-4a50-9d79-6d4770bb44e0.png)

# %% [markdown]
# Example - influentical statistics, making some kind of inference
# ![image.png](attachment:62f63685-feb7-4b28-8e5c-62469623e78d.png)

# %% [markdown]
# ![image.png](attachment:f16077d8-fe0f-4b86-a899-9b14804f9a11.png)

# %% [markdown]
# ![image.png](attachment:cf8b7414-da0a-41e3-a407-c0c18b776867.png)

# %% [markdown]
# ![image.png](attachment:51e9d5a2-699d-4e1e-8eba-1718d787529b.png)

# %% [markdown]
# ![image.png](attachment:b634d808-f824-486a-bcd0-9e9e5cae4377.png)

# %% [markdown]
# ![image.png](attachment:6c11d30c-f745-44de-ad19-6f9d3ca8e166.png)

# %%
- vote sampling  --  random sampling
- survey on privacy -- convenience sampling

# %% [markdown]
# ![image.png](attachment:53380950-786d-44ea-bddb-446de8d93689.png)

# %% [markdown]
# ![image.png](attachment:013534b3-606c-4235-bcea-38148d7e182c.png)

# %% [markdown]
# ![image.png](attachment:ec4f09ac-1306-412f-b6e3-822bae8a0c97.png)

# %% [markdown]
# ![image.png](attachment:de7c04ba-46f9-4a21-8b72-50a384806a37.png)

# %% [markdown]
# Histograms -  y axis(counts), x-axis (frequency)
#
# ![image.png](attachment:fc72cb60-dc69-4aa6-b543-78fa24e7aa20.png)
#
# when you smooth a histogram you get a probability distribution function and the y axis becomes a probability instead of counts

# %% [markdown]
# # Descriptive statistics

# %% [markdown]
# ![image.png](attachment:1c10ca43-5b18-4677-8745-2c6a0eb727b2.png)

# %% [markdown]
# ![image.png](attachment:27089503-667d-4ffc-972e-e6b930c2de92.png)
# very affected by outliers

# %% [markdown]
# ![image.png](attachment:6150d3c0-d649-41f7-b750-a43a749fba8f.png)

# %% [markdown]
# ![image.png](attachment:9140008f-3bce-4584-9829-2a8b65c0a7b5.png)

# %% [markdown]
# Populatin Variance
# ![image.png](attachment:6ccba089-ce8f-41b8-95a7-06b4f93be468.png)

# %% [markdown]
# Population Standard deviation
# ![image.png](attachment:280563e3-6cc4-49ef-8527-4a081565878c.png)

# %% [markdown]
# Sample variance
# ![image.png](attachment:d4635fd9-2082-4f8c-83f3-893680b93fc6.png)
