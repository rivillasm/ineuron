# %% [markdown]
# # STATISTICS #02

# %% [markdown]
# ![image.png](attachment:b1259e19-ab98-41dc-8256-6a4159fa78d4.png)

# %% [markdown]
# # COVARIANCE - used for feature selection, you need to know the releationship between the features

# %% [markdown]
# ![image.png](attachment:1370386f-5a15-44ff-bff7-46fe2742addf.png)

# %% [markdown]
# ![image.png](attachment:19848b87-2ac8-4632-9106-99e9df102e94.png)

# %% [markdown]
# ![image.png](attachment:f1ebbd0e-f7f1-48d1-8e2b-388679e7ea9e.png)
#
# * covariance can be positive or negative and the values can be very big so it is dificult to quantify the relationship
# * that is why other quantifiers are necessary, such as perason rank correlation coefficient

# %% [markdown]
# ![image.png](attachment:49a73c29-0c85-459e-8ef8-03d97e54555c.png)
# * the correlation coefficient of a varaible against itself is the variance

# %% [markdown]
# # Person rank correlation coefficient - ranges between [-1,+1]

# %% [markdown]
# ![image.png](attachment:0d00314e-b248-4fab-852c-c8148c0baa76.png)

# %% [markdown]
# # spearman rank correlatin coefficient

# %% [markdown]
# ![image.png](attachment:00b79338-0e89-4c46-8bec-d9a0719a0eb4.png)

# %% [markdown]
# ![image.png](attachment:718072fd-f763-4b01-a2db-41306451a7a1.png)

# %% [markdown]
# ![image.png](attachment:64355486-ecff-4cd5-aa13-6856cf742c4f.png)

# %% [markdown]
# ![image.png](attachment:5fe8eeb6-1980-4841-bd34-a52e7bd00b2d.png)

# %% [markdown]
# # Log Normal Distribution

# %% [markdown]
# ![image.png](attachment:e3c96bfe-e8b4-4af5-9c1b-62643e9253b4.png)

# %% [markdown]
# Feature trasnformation, by getting the LOG(X) you can get a log normal distribution

# %% [markdown]
# ![image.png](attachment:b0fa893b-7770-4f4e-92f1-181a06211cfa.png)

# %% [markdown]
# ![image.png](attachment:dcb74693-1c83-44a4-a012-08ca015c3d24.png)

# %% [markdown]
# # INFERENTIAL STATISTICS

# %% [markdown]
# ![image.png](attachment:13b4039d-8f70-4bcf-8d3e-42070d1bec71.png)

# %% [markdown]
# ![image.png](attachment:36837d2a-a51d-40d0-ab4e-e52f7169db30.png)

# %% [markdown]
# ![image.png](attachment:580b07c1-b82b-4cf7-8d15-c8dc65179213.png)

# %% [markdown]
# ![image.png](attachment:8776b4c5-e0cc-4d4b-b82f-8ac42427fa58.png)

# %% [markdown]
# ![image.png](attachment:f562b0ee-b9ce-426b-9cc5-29b795b5cceb.png)
