# %% [markdown]
# ![image.png](attachment:48f27d09-b74e-4eeb-b7c4-24c17dee343d.png)

# %% [markdown]
# ![image.png](attachment:070f4a0f-5665-4d4e-80fb-e42737014998.png)

# %% [markdown]
# https://towardsdatascience.com/arima-simplified-b63315f27cbc

# %% [markdown]
# ![image.png](attachment:41766e61-af48-48f8-a2f7-381d82ef2b30.png)

# %% [markdown]
# ![image.png](attachment:18e56ddc-7e8a-436a-b770-9e021efb0bbf.png)

# %% [markdown]
# ![image.png](attachment:5987dec1-5883-4636-981e-5ca058a3dfd6.png)

# %% [markdown]
# ![image.png](attachment:60a394fc-13dc-40db-91ab-04646b4f7227.png)

# %% [markdown]
# ![image.png](attachment:d94cedec-33b5-46bb-b2c8-584b0ec5ebd9.png)

# %% [markdown]
# ![image.png](attachment:9595b047-c07a-48f4-a468-079936b48832.png)

# %% [markdown]
# ![image.png](attachment:3c7670a6-c8d9-443f-8d35-744387d4af0d.png)

# %% [markdown]
# ![image.png](attachment:079718cb-5fcb-4676-97c9-b5e424b02507.png)

# %% [markdown]
# ### Example of PACF with K=2
#
# https://www.youtube.com/watch?v=DeORzP0go5I
#
#
# ![image.png](attachment:00c7d7e8-7205-4637-8763-c1061abf282b.png)
