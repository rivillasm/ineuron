# %% [markdown]
# ![image.png](attachment:899cd413-539b-4060-83c2-67a43b586803.png)

# %% [markdown]
# ![image.png](attachment:99779e08-4b7f-4f69-87b0-82b5b40049bb.png)

# %% [markdown]
# ![image.png](attachment:3f7f0441-9870-48ed-8383-ee929e60eb97.png)

# %% [markdown]
# ![image.png](attachment:1d55bd27-bed3-4aae-956b-a64fd49e20f1.png)

# %% [markdown]
# ![image.png](attachment:02ac2e0a-26ff-45b0-aea7-88674a062c95.png)
