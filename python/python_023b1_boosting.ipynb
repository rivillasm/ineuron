# %% [markdown]
# # XGBOOST

# %%
! pip show xgboost
# Out:
# Name: xgboost
# Version: 1.3.3
# Summary: XGBoost Python Package
# Home-page: https://github.com/dmlc/xgboost
# Author: None
# Author-email: None
# License: Apache-2.0
# Location: c:\programdata\anaconda3\lib\site-packages
# Requires: scipy, numpy
# Required-by:

# %%
# !pip install xgboost
# Out:
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\programdata\anaconda3\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# ![image.png](attachment:ac4fcaef-7c22-4077-bd81-7c791f120e96.png)

# %% [markdown]
# ![image.png](attachment:38fb9aef-af15-4043-8603-d41776c36927.png)

# %% [markdown]
# ![image.png](attachment:4061bad7-f9c0-41e0-ba2a-417b719962bf.png)

# %% [markdown]
# ![image.png](attachment:fc62e185-b08a-403c-98f9-d35dc3c0b8cd.png)

# %% [markdown]
# ![image.png](attachment:987298b8-8355-46c9-96a1-a2cc155ccd1e.png)

# %% [markdown]
# ![image.png](attachment:9eaaa44f-3159-48cc-ad7c-e6fc3785a298.png)

# %% [markdown]
# ![image.png](attachment:ef30e977-12e3-4477-b46b-467d32cfaf17.png)

# %% [markdown]
# ![image.png](attachment:406afd8f-d5cc-4595-9d68-942090d7e040.png)
