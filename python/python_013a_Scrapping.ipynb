# %% [markdown]
# # Flip Krat Scrapping

# %% [markdown]
# ![image.png](attachment:7653c8bc-346d-455e-900b-a8c83c27b284.png)

# %%
install the requirements.txt, go to the terminal and run :  pip install -r requirements.txt

# %% [markdown]
# ![image.png](attachment:be2593f6-a3ac-475a-8368-25397b206d3b.png)

# %%
configure the project, go to settings and select the python interpreter

# %% [markdown]
# ![image.png](attachment:519fad50-068c-4a3b-9c2d-d8b247beee5f.png)

# %%
add a new environment

# %% [markdown]
# ![image.png](attachment:6927f237-65f6-4404-9dea-b8a022cf495f.png)

# %% [markdown]
# ![image.png](attachment:29ef51a6-927a-44ad-8db8-42b69a98bd3e.png)

# %%
go to app.py

# %% [markdown]
# ![image.png](attachment:282ca62f-9b30-4f82-b19b-0815c876422c.png)

# %%
execute app.py

# %%
click on the browse link to access the application, set the search parameters

all that info should be saved in your mongodb atlas

# %% [raw]
# in mongodb atlas (https://cloud.mongodb.com/v2/619c894b6e83755cc363871f#clusters), you can create a new cluster(free), then connect to that cluster, select

# %% [markdown]
# ![image.png](attachment:cf16b628-0fe1-409e-b4d2-4ba3013fe80e.png)

# %%
TASK:

# %%
-BUILD ON SCRAPPER WHICH WILL BE ABLE TO SCRAP INFORMATION FROM WIKI, SUMMARIZE IT AND STORE IN IN DB.
-STORE ALL THE REFERRAL LINKS FOR A PARTICULAR TOPIN IN A DB
-SHOW ALL OF THIS IN A WEB PAGE
-STORE IMAGE AS WELL  (FROM IMAGE TO BASE64 AND TO DB)
- 8TH OF JANUARY dedline
deploy link and code basis(modular fashion)
