# %% [markdown]
# # DOCKERS

# %% [markdown]
# ![image.png](attachment:65f3506d-c74e-4cff-83da-05f4bdc446e7.png)

# %% [markdown]
# https://www.knowledgehut.com/blog/devops/why-use-docker

# %% [markdown]
# ![image.png](attachment:ebf49050-e108-49a0-9112-4b87c4fd76e7.png)

# %% [markdown]
# ![image.png](attachment:b5177ed0-4487-4136-8b6c-483cc0b19f60.png)

# %% [markdown]
# ![image.png](attachment:6177b897-624c-4f28-a052-ee948e3ae54d.png)

# %% [markdown]
# ![image.png](attachment:3d100c05-1a20-4c59-b2c7-30ea829575ef.png)

# %% [markdown]
# ![image.png](attachment:5e8aafb0-fe02-4f03-8cd9-b30df632a4c9.png)

# %% [markdown]
# ![image.png](attachment:b3f5f939-1439-4b92-983a-b5e4de0d8d3a.png)

# %% [markdown]
# * once you run the docker image it creates an environment with all the dependencies and configurtins and that is called a container
#
# ![image.png](attachment:cf40a2fc-f010-4975-bd8c-12e8b4259aec.png)
#
# ![image.png](attachment:307c9cda-62d4-49ac-b4d6-9f8a0fc658e6.png)

# %% [markdown]
# ![image.png](attachment:0c57cbd2-74e0-443e-851b-af9734fb0fd3.png)

# %% [markdown]
# ![image.png](attachment:06c2b71e-a12e-4f05-b1a5-b495bf8e2d61.png)

# %% [markdown]
# ![image.png](attachment:03270f7d-6936-4ee5-86eb-1241bab8c485.png)

# %% [markdown]
# ![image.png](attachment:9b02d97f-3f9e-4754-953b-f349c0323941.png)

# %% [markdown]
# # installing docker
#
# ![image.png](attachment:4edf0a86-966e-4c35-b0ae-f00ede038b1f.png)

# %% [markdown]
# ![image.png](attachment:4492e7ed-3942-4219-9f25-90aedd36d793.png)

# %% [markdown]
# * read the requirements and make sure your BIOS setting have the visualization enabled
#
# ![image.png](attachment:b539d246-1da7-4e80-91c0-5b51ca23cd13.png)
