# %% [markdown]
# # End 2 End Project - ML
#
# ![image.png](attachment:45c610dc-c91c-49aa-ae1b-74a8f4598c90.png)

# %% [markdown]
# 1- Create github repository

# %% [markdown]
# ![image.png](attachment:46ebb8e6-d286-4f06-892f-121630321516.png)

# %% [markdown]
# 2- open anaconda prompt terminal and browse to the folder location:

# %% [markdown]
# ![image.png](attachment:3158ef2a-a113-4c7a-8461-8e230bfc27be.png)

# %% [markdown]
# * lunch the vcode instance

# %% [markdown]
# ![image.png](attachment:26b3b282-67fb-4c5b-b12b-6069718a592a.png)

# %% [markdown]
# ![image.png](attachment:5a7e1ab1-3ccd-4e7c-a60a-2c443072ec49.png)

# %% [markdown]
# * create environment, you can use the bash terminal as well

# %% [markdown]
# ![image.png](attachment:9eaef418-408a-4e51-be9e-4455aee5f1c5.png)

# %% [markdown]
# * having issues with conda
#
# ![image.png](attachment:6b039381-2e21-4e09-ab59-b65c08194951.png)
