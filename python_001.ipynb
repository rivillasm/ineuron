# %% [markdown]
# ## dictionaries

# %%
# dictionary comprehension
d = {i:i**2 for i in range (10)}
d
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
d.items()
# Out:
# dict_items([(0, 0), (1, 1), (2, 4), (3, 9), (4, 16), (5, 25), (6, 36), (7, 49), (8, 64), (9, 81)])

# %%
d[4]
# Out:
# 16

# %%
type(d.items())
# Out:
# dict_items

# %%
list(d.items())
# Out:
# [(0, 0),
#  (1, 1),
#  (2, 4),
#  (3, 9),
#  (4, 16),
#  (5, 25),
#  (6, 36),
#  (7, 49),
#  (8, 64),
#  (9, 81)]

# %% [markdown]
# # FUNCTIONS

# %%
def is_prime(num):
    for i in range(2,num):
        if num % i == 0:
            print(f'this number {num} is not a prime number')
            break
    else:
        print(f'this number {num} is a prime number')

# %%
is_prime(2)
# Out:
# this numer 2 is a prime number

# %%
next(iter('mario'))
# Out:
# 'm'

# %%
a=iter('mario')
a

# %%
next(a)
# Out:
# 'r'

# %%
next(iter(str(12)))
# Out:
# '1'

# %% [markdown]
# generator functions are a special kind of function that return a lazy iterator. These are objects that you can loop over like a list. However, unlike lists, lazy iterators do not store their contents in memory.

# %%
# The Yield keyword in Python is similar to a return statement used for returning values 
# or objects in Python. However, there is a slight difference. 
# The yield statement returns a generator object to the one who calls the function which contains yield, 
# instead of simply returning a value. 

# In Python, generator functions are those functions that, instead of returning a single value, 
# return an iterable generator object. You can access or read the values returned from the generator 
# function stored inside a generator object one-by-one using a simple loop or using next() 
# or list() methods.

def gencube(n):
    for i in range(n):
        yield i**3      #convers the function into generator
        
print(type(gencube(10)))
# Out:
# <class 'generator'>

# %%
for i in gencube(10):
    print(i)
# Out:
# 0
# 1
# 8
# 27
# 64
# 125
# 216
# 343
# 512
# 729

# %% [markdown]
# # MAP Functions

# %%
def square(n):
    return n**2

square(4)
# Out:
# 16

# %%
l=[3,4,5,6,7]
n=[]
for i in l:
    n.append(square(i))

n
# Out:
# [9, 16, 25, 36, 49]

# %%
# list comprehension
[i**2 for i in l]
# Out:
# [9, 16, 25, 36, 49]

# %%
# map(func,*iterables)---> map object
list(map(square,l))
# Out:
# [9, 16, 25, 36, 49]

# %%
for i in map(square,l):
    print(i)
# Out:
# 9
# 16
# 25
# 36
# 49

# %% [markdown]
# # lambda operation

# %%
l
# Out:
# [3, 4, 5, 6, 7]

# %%
# A lambda function is a small anonymous function.
# A lambda function can take any number of arguments, but can only have one expression.


list(map(lambda x: x**2,l))
# Out:
# [9, 16, 25, 36, 49]

# %%
c=lambda x: x**2
list(map(c,l))
# Out:
# [9, 16, 25, 36, 49]

# %%
a=[1,2,3,4,5]
b=[5,6,7,8,9]
c=[2,4,6,8,9,6]

# %%
def summation(x,y,z):
    return x+y+z

# %%
list(map(summation,a,b,c))
# Out:
# [8, 12, 16, 20, 23]

# %%
list(map(lambda x,y,z: x+y+z, a,b,c))
# Out:
# [8, 12, 16, 20, 23]

# %% [markdown]
# # Reduce function

# %%
# reduce(function, sequence[, initial]) -> value
# reduce does not allow more than two arguments
from functools import reduce

# %%
l = [4,5,6,7,8,9]

# %%
def summation(a,b):
    return a+b

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
reduce(summation,l)
# Out:
# 39

# %%
reduce(lambda x,y: x+y,l)
# Out:
# 39

# %% [markdown]
# # FILTER

# %%
# filter(self, /, *args, **kwargs)
l=[4,5,6,7,8,6,7,8,8]

# %%
list(filter(lambda x:x%2==0,l))
# Out:
# [4, 6, 8, 6, 8, 8]

# %%
def even_check(n):
    if n%2==0:
        return True

# %%
list(filter(even_check,l))
# Out:
# [4, 6, 8, 6, 8, 8]
